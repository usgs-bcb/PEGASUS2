# %% [markdown]
# At this point, all records accepted into OBIS have taxonomic names as a primary attribute and focus of the observations (and measurements in some cases), most of which have been validated against the World Register of Marine Species (WoRMS). In order to get a sense for the institutions, datasets, and other characteristics of the data in OBIS that may help contribute to the Essential Ocean Variables for Biodiversity, it will be useful to assemble a mapping of higher level taxonomic identifiers from WoRMS that can be used in queries where OBIS supports the unambiguous use of "taxonid."
#
# This notebook provides a setup process for working with OBIS data using taxonomic identifiers. It builds and updates a file, eov_packet.json, stored here that contains a list of the [EOVs for Biodiversity](http://www.goosocean.org/index.php?option=com_content&view=article&id=14&Itemid=114) and some related details. Each EOV record has, for now, a supplied list of taxon names that can be tweaked over time as we refine the process for working with OBIS. Since the initial point is to build on what's in OBIS, I started with the dynamic list of Classes in OBIS retrieved via https://api.obis.org/statistics/composition/class. For mangroves and seagrasses, I had to set a list at the Family level since the species we have records for are all in Class Magnoliopsida. This also presents a list to work against to identify any important taxonomic groups for the EOVs that are not yet represented in OBIS.
#
# Starting from the taxa list (stored in the property, obis_worms_taxa_list), the code runs through an update/summarization process to query a couple of different API routes in OBIS to assemble useful data to then drive a number of other processes and reports. Operationally, we can use this process or something like it to routinely update this process because of either new data in OBIS or a revised list of taxa groups for the EOVs. As we settle in on the latter, we can also add properties to OBIS itself that will associate EOVs into the data system.
#
# We will need to do some work on these lists, which are very simplistic at the moment. Ultimately, we need more than taxon names for some of the EOVs such as the plankton groups where we need life history details in the data to determine species ecosystem function. In the near term, these dynamics will be a bit problematic where the integrated observation data is concerned as we lack that kind of observational detail in OBIS, WoRMS, and many of the datasets we are analyzing against. We may need to introduce some type of more complex algorithm for working with the data, including some way of characterizing uncertainty in the observation record as they relate to calculating subvariables or building derivative reports.

# %%
from IPython.display import display
import requests
import json
from datetime import datetime
import pegasus_functions as pf

# %%
eov_packet = pf.get_eov_packet()

# %%
new_eov_doc = dict()
for eov,config in eov_packet.items():
    # Set up a new dictionary object for the EOV
    new_eov_doc[eov] = dict()
    # Copy in the constant variables we will maintain
    new_eov_doc[eov]["label"] = config["label"]
    new_eov_doc[eov]["url"] = config["url"]
    # The simple list of higher level taxa names will likely be the thing that changes over time
    new_eov_doc[eov]["obis_worms_taxa_list"] = config["obis_worms_taxa_list"]
    
    # Set up new dictionary structure to contain the taxa summary from OBIS/WoRMS
    new_eov_doc[eov]["obis_worms_taxa"] = dict()

    # Loop through the supplied taxa names for an EOV and retrieve details from the OBIS API
    for taxon in config["obis_worms_taxa_list"]:
        # Retrieve the taxon report for the supplied name
        url_obis_taxon = f"https://api.obis.org/taxon/{taxon}"
        try:
            r_obis_taxon = requests.get(url_obis_taxon).json()
            usable_result = next((r for r in r_obis_taxon["results"] if r["taxonRank"] in ["Family","Class","Subphylum"]), None)
        except Exception as e:
            usable_result = None
            print(e)
            print(url_obis_taxon)

        if usable_result is None:
            # Print out a message if we fail to get a valid result from the API for some reason
            print(taxon, "NOT FOUND")
        else:
            # Start the taxon record with the high level taxon result from the OBIA API
            new_eov_doc[eov]["obis_worms_taxa"][taxon] = usable_result
            # Record the API url we used and the date we cached the information
            new_eov_doc[eov]["obis_worms_taxa"][taxon]["api"] = url_obis_taxon
            new_eov_doc[eov]["obis_worms_taxa"][taxon]["date_cached"] = datetime.utcnow().isoformat()
            
            # Set up a process to retrieve summary results on the observation records in OBIS for the taxon
            url_summary_stats = f"https://api.obis.org/statistics/all?taxonid={usable_result['taxonID']}"
            try:
                # Retrieve and record summary stats for the taxon in the data structure along with the API route and date/time
                r_summary_stats = requests.get(url_summary_stats).json()
                new_eov_doc[eov]["obis_worms_taxa"][taxon]["summary_stats"] = r_summary_stats
                new_eov_doc[eov]["obis_worms_taxa"][taxon]["summary_stats"]["api"] = url_summary_stats
                new_eov_doc[eov]["obis_worms_taxa"][taxon]["summary_stats"]["date_cached"] = datetime.utcnow().isoformat()
            except:
                # Print out the URL we tried here in case it failed for some reason
                print(url_summary_stats)
# Out:
# https://api.obis.org/statistics/all?taxonid=1070
# https://api.obis.org/statistics/all?taxonid=794

# %%
# Show what the new document looks like
display(new_eov_doc)
# Out:
# {'coral': {'label': 'Hard coral cover and composition',
#   'obis_worms_taxa': {'Anthozoa': {'acceptedNameUsage': 'Anthozoa',
#     'acceptedNameUsageID': 1292,
#     'api': 'https://api.obis.org/taxon/Anthozoa',
#     'class': 'Anthozoa',
#     'classid': 1292,
#     'date_cached': '2019-03-03T13:17:55.545118',
#     'is_brackish': True,
#     'is_marine': True,
#     'is_terrestrial': False,
#     'kingdom': 'Animalia',
#     'kingdomid': 2,
#     'phylum': 'Cnidaria',
#     'phylumid': 1267,
#     'scientificName': 'Anthozoa',
#     'scientificNameAuthorship': 'Ehrenberg, 1834',
#     'summary_stats': {'api': 'https://api.obis.org/statistics/all?taxonid=1292',
#      'datasets': 447,
#      'date_cached': '2019-03-03T13:17:56.569209',
#      'records': 1249114,
#      'species': 5336,
#      'specieslevel': 772924,
#      'taxa': 6312,
#      'yearrange': [1758, 2018]},
#     'taxonID': 1292,
#     'taxonRank': 'Class',
#     'taxonomicStatus': 'accepted'},
#    'Ascidiacea': {'acceptedNameUsage': 'Ascidiacea',
#     'acceptedNameUsageID': 1839,
#     'api': 'https://api.obis.org/taxon/Ascidiacea',
#     'class': 'Ascidiacea',
#     'classid': 1839,
#     'date_cached': '2019-03-03T13:18:01.896951',
#     'is_marine': True,
#     'kingdom': 'Animalia',
#     'kingdomid': 2,
#     'phylum': 'Chordata',
#     'phylumid': 1821,
#     'scientificName': 'Ascidiacea',
#     'scientificNameAuthorship': 'Blainville, 1824',
#     'subphylum': 'Tunicata',
#     'subphylumid': 146420,
#     'summary_stats': {'api': 'https://api.obis.org/statistics/all?taxonid=1839',
#      'datasets': 316,
#      'date_cached': '2019-03-03T13:18:02.715874',
#      'records': 92547,
#      'species': 1551,
#      'specieslevel': 60712,
#      'taxa': 1606,
#      'yearrange': [1868, 2018]},
#     'taxonID': 1839,
#     'taxonRank': 'Class',
#     'taxonomicStatus': 'accepted'},
#    'Calcarea': {'acceptedNameUsage': 'Calcarea',
#     'acceptedNameUsageID': 559,
#     'api': 'https://api.obis.org/taxon/Calcarea',
#     'class': 'Calcarea',
#     'classid': 559,
#     'date_cached': '2019-03-03T13:18:05.993617',
#     'is_brackish': False,
#     'is_freshwater': False,
#     'is_marine': True,
#     'is_terrestrial': False,
#     'kingdom': 'Animalia',
#     'kingdomid': 2,
#     'phylum': 'Porifera',
#     'phylumid': 558,
#     'scientificName': 'Calcarea',
#     'scientificNameAuthorship': 'Bowerbank, 1862',
#     'summary_stats': {'api': 'https://api.obis.org/statistics/all?taxonid=559',
#      'datasets': 127,
#      'date_cached': '2019-03-03T13:18:06.809386',
#      'records': 10639,
#      'species': 478,
#      'specieslevel': 6996,
#      'taxa': 529,
#      'yearrange': [1842, 2018]},
#     'taxonID': 559,
#     'taxonRank': 'Class',
#     'taxonomicStatus': 'accepted'},
#    'Demospongiae': {'acceptedNameUsage': 'Demospongiae',
#     'acceptedNameUsageID': 164811,
#     'api': 'https://api.obis.org/taxon/Demospongiae',
#     'class': 'Demospongiae',
#     'classid': 164811,
#     'date_cached': '2019-03-03T13:17:57.796390',
#     'is_brackish': False,
#     'is_freshwater': False,
#     'is_marine': True,
#     'is_terrestrial': False,
#     'kingdom': 'Animalia',
#     'kingdomid': 2,
#     'phylum': 'Porifera',
#     'phylumid': 558,
#     'scientificName': 'Demospongiae',
#     'scientificNameAuthorship': 'Sollas, 1885',
#     'summary_stats': {'api': 'https://api.obis.org/statistics/all?taxonid=164811',
#      'datasets': 244,
#      'date_cached': '2019-03-03T13:17:58.618811',
#      'records': 227158,
#      'species': 5863,
#      'specieslevel': 95856,
#      'taxa': 6323,
#      'yearrange': [1691, 2018]},
#     'taxonID': 164811,
#     'taxonRank': 'Class',
#     'taxonomicStatus': 'accepted'},
#    'Gymnolaemata': {'acceptedNameUsage': 'Gymnolaemata',
#     'acceptedNameUsageID': 1795,
#     'api': 'https://api.obis.org/taxon/Gymnolaemata',
#     'class': 'Gymnolaemata',
#     'classid': 1795,
#     'date_cached': '2019-03-03T13:17:59.845500',
#     'is_brackish': True,
#     'is_freshwater': True,
#     'is_marine': True,
#     'is_terrestrial': False,
#     'kingdom': 'Animalia',
#     'kingdomid': 2,
#     'phylum': 'Bryozoa',
#     'phylumid': 146142,
#     'scientificName': 'Gymnolaemata',
#     'scientificNameAuthorship': 'Allman, 1856',
#     'summary_stats': {'api': 'https://api.obis.org/statistics/all?taxonid=1795',
#      'datasets': 218,
#      'date_cached': '2019-03-03T13:18:00.563183',
#      'records': 166354,
#      'species': 2487,
#      'specieslevel': 140802,
#      'taxa': 3028,
#      'yearrange': [1816, 2017]},
#     'taxonID': 1795,
#     'taxonRank': 'Class',
#     'taxonomicStatus': 'accepted'},
#    'Hexactinellida': {'acceptedNameUsage': 'Hexactinellida',
#     'acceptedNameUsageID': 22612,
#     'api': 'https://api.obis.org/taxon/Hexactinellida',
#     'class': 'Hexactinellida',
#     'classid': 22612,
#     'date_cached': '2019-03-03T13:18:03.943475',
#     'is_brackish': False,
#     'is_freshwater': False,
#     'is_marine': True,
#     'is_terrestrial': False,
#     'kingdom': 'Animalia',
#     'kingdomid': 2,
#     'phylum': 'Porifera',
#     'phylumid': 558,
#     'scientificName': 'Hexactinellida',
#     'scientificNameAuthorship': 'Schmidt, 1870',
#     'summary_stats': {'api': 'https://api.obis.org/statistics/all?taxonid=22612',
#      'datasets': 75,
#      'date_cached': '2019-03-03T13:18:04.742981',
#      'records': 29553,
#      'species': 554,
#      'specieslevel': 12210,
#      'taxa': 676,
#      'yearrange': [1840, 2017]},
#     'taxonID': 22612,
#     'taxonRank': 'Class',
#     'taxonomicStatus': 'accepted'}},
#   'obis_worms_taxa_list': ['Anthozoa',
#    'Demospongiae',
#    'Gymnolaemata',
#    'Ascidiacea',
#    'Hexactinellida',
#    'Calcarea'],
#   'url': 'http://www.goosocean.org/index.php?option=com_oe&task=viewDocumentRecord&docID=17512'},
#  'fish': {'label': 'Fish abundance and distribution',
#   'obis_worms_taxa': {'Actinopterygii': {'acceptedNameUsage': 'Actinopterygii',
#     'acceptedNameUsageID': 10194,
#     'api': 'https://api.obis.org/taxon/Actinopterygii',
#     'class': 'Actinopterygii',
#     'classid': 10194,
#     'date_cached': '2019-03-03T13:18:08.039355',
#     'is_marine': True,
#     'kingdom': 'Animalia',
#     'kingdomid': 2,
#     'phylum': 'Chordata',
#     'phylumid': 1821,
#     'scientificName': 'Actinopterygii',
#     'subphylum': 'Vertebrata',
#     'subphylumid': 146419,
#     'summary_stats': {'api': 'https://api.obis.org/statistics/all?taxonid=10194',
#      'datasets': 811,
#      'date_cached': '2019-03-03T13:18:08.839592',
#      'records': 26399857,
#      'species': 16441,
#      'specieslevel': 24514191,
#      'taxa': 19928,
#      'yearrange': [1643, 2018]},
#     'superclass': 'Pisces',
#     'superclassid': 11676,
#     'taxonID': 10194,
#     'taxonRank': 'Class',
#     'taxonomicStatus': 'accepted'},
#    'Elasmobranchii': {'acceptedNameUsage': 'Elasmobranchii',
#     'acceptedNameUsageID': 10193,
#     'api': 'https://api.obis.org/taxon/Elasmobranchii',
#     'class': 'Elasmobranchii',
#     'classid': 10193,
#     'date_cached': '2019-03-03T13:18:10.077103',
#     'is_marine': True,
#     'kingdom': 'Animalia',
#     'kingdomid': 2,
#     'phylum': 'Chordata',
#     'phylumid': 1821,
#     'scientificName': 'Elasmobranchii',
#     'subphylum': 'Vertebrata',
#     'subphylumid': 146419,
#     'summary_stats': {'api': 'https://api.obis.org/statistics/all?taxonid=10193',
#      'datasets': 499,
#      'date_cached': '2019-03-03T13:18:10.645388',
#      'records': 2138370,
#      'species': 1015,
#      'specieslevel': 1948534,
#      'taxa': 1196,
#      'yearrange': [1758, 2018]},
#     'superclass': 'Pisces',
#     'superclassid': 11676,
#     'taxonID': 10193,
#     'taxonRank': 'Class',
#     'taxonomicStatus': 'accepted'},
#    'Holocephali': {'acceptedNameUsage': 'Holocephali',
#     'acceptedNameUsageID': 10196,
#     'api': 'https://api.obis.org/taxon/Holocephali',
#     'class': 'Holocephali',
#     'classid': 10196,
#     'date_cached': '2019-03-03T13:18:11.499505',
#     'is_marine': True,
#     'kingdom': 'Animalia',
#     'kingdomid': 2,
#     'phylum': 'Chordata',
#     'phylumid': 1821,
#     'scientificName': 'Holocephali',
#     'subphylum': 'Vertebrata',
#     'subphylumid': 146419,
#     'summary_stats': {'api': 'https://api.obis.org/statistics/all?taxonid=10196',
#      'datasets': 115,
#      'date_cached': '2019-03-03T13:18:12.075822',
#      'records': 60170,
#      'species': 43,
#      'specieslevel': 57685,
#      'taxa': 51,
#      'yearrange': [1865, 2016]},
#     'superclass': 'Pisces',
#     'superclassid': 11676,
#     'taxonID': 10196,
#     'taxonRank': 'Class',
#     'taxonomicStatus': 'accepted'},
#    'Myxini': {'acceptedNameUsage': 'Myxini',
#     'acceptedNameUsageID': 10189,
#     'api': 'https://api.obis.org/taxon/Myxini',
#     'class': 'Myxini',
#     'classid': 10189,
#     'date_cached': '2019-03-03T13:18:12.892588',
#     'is_marine': True,
#     'kingdom': 'Animalia',
#     'kingdomid': 2,
#     'phylum': 'Chordata',
#     'phylumid': 1821,
#     'scientificName': 'Myxini',
#     'subphylum': 'Vertebrata',
#     'subphylumid': 146419,
#     'summary_stats': {'api': 'https://api.obis.org/statistics/all?taxonid=10189',
#      'datasets': 92,
#      'date_cached': '2019-03-03T13:18:13.776790',
#      'records': 16607,
#      'species': 65,
#      'specieslevel': 14731,
#      'taxa': 71,
#      'yearrange': [1835, 2017]},
#     'superclass': 'Agnatha',
#     'superclassid': 1829,
#     'taxonID': 10189,
#     'taxonRank': 'Class',
#     'taxonomicStatus': 'accepted'}},
#   'obis_worms_taxa_list': ['Actinopterygii',
#    'Elasmobranchii',
#    'Holocephali',
#    'Myxini'],
#   'url': 'http://www.goosocean.org/index.php?option=com_oe&task=viewDocumentRecord&docID=17510'},
#  'invertebrates': {'label': 'Invertebrate abundance and distribution',
#   'obis_worms_taxa': {'Asteroidea': {'acceptedNameUsage': 'Asteroidea',
#     'acceptedNameUsageID': 123080,
#     'api': 'https://api.obis.org/taxon/Asteroidea',
#     'class': 'Asteroidea',
#     'classid': 123080,
#     'date_cached': '2019-03-03T13:19:40.031855',
#     'is_brackish': False,
#     'is_freshwater': False,
#     'is_marine': True,
#     'is_terrestrial': False,
#     'kingdom': 'Animalia',
#     'kingdomid': 2,
#     'phylum': 'Echinodermata',
#     'phylumid': 1806,
#     'scientificName': 'Asteroidea',
#     'scientificNameAuthorship': 'de Blainville, 1830',
#     'subphylum': 'Asterozoa',
#     'subphylumid': 148743,
#     'summary_stats': {'api': 'https://api.obis.org/statistics/all?taxonid=123080',
#      'datasets': 372,
#      'date_cached': '2019-03-03T13:19:40.815653',
#      'records': 212434,
#      'species': 1524,
#      'specieslevel': 151426,
#      'taxa': 1917,
#      'yearrange': [1758, 2018]},
#     'taxonID': 123080,
#     'taxonRank': 'Class',
#     'taxonomicStatus': 'accepted'},
#    'Bivalvia': {'acceptedNameUsage': 'Bivalvia',
#     'acceptedNameUsageID': 105,
#     'api': 'https://api.obis.org/taxon/Bivalvia',
#     'class': 'Bivalvia',
#     'classid': 105,
#     'date_cached': '2019-03-03T13:19:29.960162',
#     'is_brackish': True,
#     'is_freshwater': True,
#     'is_marine': True,
#     'kingdom': 'Animalia',
#     'kingdomid': 2,
#     'phylum': 'Mollusca',
#     'phylumid': 51,
#     'scientificName': 'Bivalvia',
#     'scientificNameAuthorship': 'Linnaeus, 1758',
#     'summary_stats': {'api': 'https://api.obis.org/statistics/all?taxonid=105',
#      'datasets': 669,
#      'date_cached': '2019-03-03T13:19:30.782254',
#      'records': 1254609,
#      'species': 5148,
#      'specieslevel': 1052182,
#      'taxa': 5826,
#      'yearrange': [1698, 2018]},
#     'taxonID': 105,
#     'taxonRank': 'Class',
#     'taxonomicStatus': 'accepted'},
#    'Branchiopoda': {'acceptedNameUsage': 'Branchiopoda',
#     'acceptedNameUsageID': 1069,
#     'api': 'https://api.obis.org/taxon/Branchiopoda',
#     'class': 'Branchiopoda',
#     'classid': 1069,
#     'date_cached': '2019-03-03T13:18:18.894612',
#     'is_brackish': True,
#     'is_freshwater': True,
#     'is_marine': True,
#     'is_terrestrial': False,
#     'kingdom': 'Animalia',
#     'kingdomid': 2,
#     'phylum': 'Arthropoda',
#     'phylumid': 1065,
#     'scientificName': 'Branchiopoda',
#     'scientificNameAuthorship': 'Latreille, 1817',
#     'subphylum': 'Crustacea',
#     'subphylumid': 1066,
#     'summary_stats': {'api': 'https://api.obis.org/statistics/all?taxonid=1069',
#      'datasets': 190,
#      'date_cached': '2019-03-03T13:18:19.640895',
#      'records': 121335,
#      'species': 106,
#      'specieslevel': 60704,
#      'taxa': 158,
#      'yearrange': [1849, 2018]},
#     'taxonID': 1069,
#     'taxonRank': 'Class',
#     'taxonomicStatus': 'accepted'},
#    'Chromadorea': {'acceptedNameUsage': 'Chromadorea',
#     'acceptedNameUsageID': 731848,
#     'api': 'https://api.obis.org/taxon/Chromadorea',
#     'class': 'Chromadorea',
#     'classid': 731848,
#     'date_cached': '2019-03-03T13:19:49.213238',
#     'is_brackish': True,
#     'is_freshwater': True,
#     'is_marine': True,
#     'is_terrestrial': True,
#     'kingdom': 'Animalia',
#     'kingdomid': 2,
#     'phylum': 'Nematoda',
#     'phylumid': 799,
#     'scientificName': 'Chromadorea',
#     'summary_stats': {'api': 'https://api.obis.org/statistics/all?taxonid=731848',
#      'datasets': 122,
#      'date_cached': '2019-03-03T13:19:50.031265',
#      'records': 89044,
#      'species': 2135,
#      'specieslevel': 47377,
#      'taxa': 2596,
#      'yearrange': [1809, 2016]},
#     'taxonID': 731848,
#     'taxonRank': 'Class',
#     'taxonomicStatus': 'accepted'},
#    'Clitellata': {'acceptedNameUsage': 'Clitellata',
#     'acceptedNameUsageID': 14165,
#     'api': 'https://api.obis.org/taxon/Clitellata',
#     'class': 'Clitellata',
#     'classid': 14165,
#     'date_cached': '2019-03-03T13:19:43.720876',
#     'is_marine': True,
#     'kingdom': 'Animalia',
#     'kingdomid': 2,
#     'phylum': 'Annelida',
#     'phylumid': 882,
#     'scientificName': 'Clitellata',
#     'summary_stats': {'api': 'https://api.obis.org/statistics/all?taxonid=14165',
#      'datasets': 248,
#      'date_cached': '2019-03-03T13:19:44.309576',
#      'records': 117451,
#      'species': 559,
#      'specieslevel': 44516,
#      'taxa': 684,
#      'yearrange': [1791, 2018]},
#     'taxonID': 14165,
#     'taxonRank': 'Class',
#     'taxonomicStatus': 'accepted'},
#    'Crinoidea': {'acceptedNameUsage': 'Crinoidea',
#     'acceptedNameUsageID': 123081,
#     'api': 'https://api.obis.org/taxon/Crinoidea',
#     'class': 'Crinoidea',
#     'classid': 123081,
#     'date_cached': '2019-03-03T13:19:47.164185',
#     'is_marine': True,
#     'kingdom': 'Animalia',
#     'kingdomid': 2,
#     'phylum': 'Echinodermata',
#     'phylumid': 1806,
#     'scientificName': 'Crinoidea',
#     'subphylum': 'Crinozoa',
#     'subphylumid': 147423,
#     'summary_stats': {'api': 'https://api.obis.org/statistics/all?taxonid=123081',
#      'datasets': 168,
#      'date_cached': '2019-03-03T13:19:47.982770',
#      'records': 39753,
#      'species': 532,
#      'specieslevel': 25400,
#      'taxa': 650,
#      'yearrange': [1758, 2017]},
#     'taxonID': 123081,
#     'taxonRank': 'Class',
#     'taxonomicStatus': 'accepted'},
#    'Echinoidea': {'acceptedNameUsage': 'Echinoidea',
#     'acceptedNameUsageID': 123082,
#     'api': 'https://api.obis.org/taxon/Echinoidea',
#     'class': 'Echinoidea',
#     'classid': 123082,
#     'date_cached': '2019-03-03T13:19:42.055250',
#     'is_brackish': False,
#     'is_freshwater': False,
#     'is_marine': True,
#     'is_terrestrial': False,
#     'kingdom': 'Animalia',
#     'kingdomid': 2,
#     'phylum': 'Echinodermata',
#     'phylumid': 1806,
#     'scientificName': 'Echinoidea',
#     'scientificNameAuthorship': 'Leske, 1778',
#     'subphylum': 'Echinozoa',
#     'subphylumid': 148744,
#     'summary_stats': {'api': 'https://api.obis.org/statistics/all?taxonid=123082',
#      'datasets': 359,
#      'date_cached': '2019-03-03T13:19:42.864160',
#      'records': 171185,
#      'species': 842,
#      'specieslevel': 125706,
#      'taxa': 1049,
#      'yearrange': [1720, 2018]},
#     'taxonID': 123082,
#     'taxonRank': 'Class',
#     'taxonomicStatus': 'accepted'},
#    'Enoplea': {'acceptedNameUsage': 'Enoplea',
#     'acceptedNameUsageID': 834422,
#     'api': 'https://api.obis.org/taxon/Enoplea',
#     'class': 'Enoplea',
#     'classid': 834422,
#     'date_cached': '2019-03-03T13:19:51.261186',
#     'is_brackish': True,
#     'is_freshwater': True,
#     'is_marine': True,
#     'is_terrestrial': True,
#     'kingdom': 'Animalia',
#     'kingdomid': 2,
#     'phylum': 'Nematoda',
#     'phylumid': 799,
#     'scientificName': 'Enoplea',
#     'summary_stats': {'api': 'https://api.obis.org/statistics/all?taxonid=834422',
#      'datasets': 128,
#      'date_cached': '2019-03-03T13:19:52.080247',
#      'records': 21001,
#      'species': 849,
#      'specieslevel': 11596,
#      'taxa': 956,
#      'yearrange': [1888, 2016]},
#     'taxonID': 834422,
#     'taxonRank': 'Class',
#     'taxonomicStatus': 'accepted'},
#    'Enteropneusta': {'acceptedNameUsage': 'Enteropneusta',
#     'acceptedNameUsageID': 1820,
#     'api': 'https://api.obis.org/taxon/Enteropneusta',
#     'class': 'Enteropneusta',
#     'classid': 1820,
#     'date_cached': '2019-03-03T13:21:06.768549',
#     'is_freshwater': False,
#     'is_marine': True,
#     'is_terrestrial': False,
#     'kingdom': 'Animalia',
#     'kingdomid': 2,
#     'phylum': 'Hemichordata',
#     'phylumid': 1818,
#     'scientificName': 'Enteropneusta',
#     'scientificNameAuthorship': 'Gegenbaur, 1870',
#     'summary_stats': {'api': 'https://api.obis.org/statistics/all?taxonid=1820',
#      'datasets': 88,
#      'date_cached': '2019-03-03T13:21:07.652061',
#      'records': 8860,
#      'species': 39,
#      'specieslevel': 700,
#      'taxa': 51,
#      'yearrange': [1825, 2018]},
#     'taxonID': 1820,
#     'taxonRank': 'Class',
#     'taxonomicStatus': 'accepted'},
#    'Gastropoda': {'acceptedNameUsage': 'Gastropoda',
#     'acceptedNameUsageID': 101,
#     'api': 'https://api.obis.org/taxon/Gastropoda',
#     'class': 'Gastropoda',
#     'classid': 101,
#     'date_cached': '2019-03-03T13:19:27.911136',
#     'is_brackish': True,
#     'is_freshwater': True,
#     'is_marine': True,
#     'is_terrestrial': True,
#     'kingdom': 'Animalia',
#     'kingdomid': 2,
#     'phylum': 'Mollusca',
#     'phylumid': 51,
#     'scientificName': 'Gastropoda',
#     'scientificNameAuthorship': 'Cuvier, 1795',
#     'summary_stats': {'api': 'https://api.obis.org/statistics/all?taxonid=101',
#      'datasets': 698,
#      'date_cached': '2019-03-03T13:19:28.732484',
#      'records': 1488609,
#      'species': 17774,
#      'specieslevel': 988593,
#      'taxa': 20112,
#      'yearrange': [1027, 2018]},
#     'taxonID': 101,
#     'taxonRank': 'Class',
#     'taxonomicStatus': 'accepted'},
#    'Hexanauplia': {'acceptedNameUsage': 'Hexanauplia',
#     'acceptedNameUsageID': 889925,
#     'api': 'https://api.obis.org/taxon/Hexanauplia',
#     'class': 'Hexanauplia',
#     'classid': 889925,
#     'date_cached': '2019-03-03T13:18:15.018404',
#     'is_brackish': True,
#     'is_freshwater': True,
#     'is_marine': True,
#     'kingdom': 'Animalia',
#     'kingdomid': 2,
#     'phylum': 'Arthropoda',
#     'phylumid': 1065,
#     'scientificName': 'Hexanauplia',
#     'scientificNameAuthorship': 'Oakley, Wolfe, Lindgren & Zaharof, 2013',
#     'subphylum': 'Crustacea',
#     'subphylumid': 1066,
#     'summary_stats': {'api': 'https://api.obis.org/statistics/all?taxonid=889925',
#      'datasets': 570,
#      'date_cached': '2019-03-03T13:18:15.822375',
#      'records': 3917741,
#      'species': 5570,
#      'specieslevel': 2155960,
#      'taxa': 7030,
#      'yearrange': [1758, 2018]},
#     'superclass': 'Multicrustacea',
#     'superclassid': 845959,
#     'taxonID': 889925,
#     'taxonRank': 'Class',
#     'taxonomicStatus': 'accepted'},
#    'Holothuroidea': {'acceptedNameUsage': 'Holothuroidea',
#     'acceptedNameUsageID': 123083,
#     'api': 'https://api.obis.org/taxon/Holothuroidea',
#     'class': 'Holothuroidea',
#     'classid': 123083,
#     'date_cached': '2019-03-03T13:19:45.131289',
#     'is_marine': True,
#     'kingdom': 'Animalia',
#     'kingdomid': 2,
#     'phylum': 'Echinodermata',
#     'phylumid': 1806,
#     'scientificName': 'Holothuroidea',
#     'subphylum': 'Echinozoa',
#     'subphylumid': 148744,
#     'summary_stats': {'api': 'https://api.obis.org/statistics/all?taxonid=123083',
#      'datasets': 323,
#      'date_cached': '2019-03-03T13:19:45.935204',
#      'records': 105888,
#      'species': 1140,
#      'specieslevel': 81544,
#      'taxa': 1349,
#      'yearrange': [1775, 2018]},
#     'taxonID': 123083,
#     'taxonRank': 'Class',
#     'taxonomicStatus': 'accepted'},
#    'Hoplonemertea': {'acceptedNameUsage': 'Hoplonemertea',
#     'acceptedNameUsageID': 122309,
#     'api': 'https://api.obis.org/taxon/Hoplonemertea',
#     'class': 'Hoplonemertea',
#     'classid': 122309,
#     'date_cached': '2019-03-03T13:21:12.567170',
#     'is_marine': True,
#     'kingdom': 'Animalia',
#     'kingdomid': 2,
#     'phylum': 'Nemertea',
#     'phylumid': 152391,
#     'scientificName': 'Hoplonemertea',
#     'scientificNameAuthorship': 'Hubrecht, 1879',
#     'summary_stats': {'api': 'https://api.obis.org/statistics/all?taxonid=122309',
#      'datasets': 59,
#      'date_cached': '2019-03-03T13:21:13.383709',
#      'records': 6533,
#      'species': 55,
#      'specieslevel': 6217,
#      'taxa': 71,
#      'yearrange': [1873, 2018]},
#     'taxonID': 122309,
#     'taxonRank': 'Class',
#     'taxonomicStatus': 'accepted'},
#    'Insecta': {'acceptedNameUsage': 'Insecta',
#     'acceptedNameUsageID': 1307,
#     'api': 'https://api.obis.org/taxon/Insecta',
#     'class': 'Insecta',
#     'classid': 1307,
#     'date_cached': '2019-03-03T13:18:20.737278',
#     'is_marine': True,
#     'kingdom': 'Animalia',
#     'kingdomid': 2,
#     'phylum': 'Arthropoda',
#     'phylumid': 1065,
#     'scientificName': 'Insecta',
#     'subphylum': 'Hexapoda',
#     'subphylumid': 1278,
#     'summary_stats': {'api': 'https://api.obis.org/statistics/all?taxonid=1307',
#      'datasets': 164,
#      'date_cached': '2019-03-03T13:18:21.555999',
#      'records': 61089,
#      'species': 254,
#      'specieslevel': 9269,
#      'taxa': 470,
#      'yearrange': [1780, 2018]},
#     'taxonID': 1307,
#     'taxonRank': 'Class',
#     'taxonomicStatus': 'accepted'},
#    'Malacostraca': {'acceptedNameUsage': 'Malacostraca',
#     'acceptedNameUsageID': 1071,
#     'api': 'https://api.obis.org/taxon/Malacostraca',
#     'class': 'Malacostraca',
#     'classid': 1071,
#     'date_cached': '2019-03-03T13:18:16.871930',
#     'is_brackish': True,
#     'is_freshwater': True,
#     'is_marine': True,
#     'is_terrestrial': True,
#     'kingdom': 'Animalia',
#     'kingdomid': 2,
#     'phylum': 'Arthropoda',
#     'phylumid': 1065,
#     'scientificName': 'Malacostraca',
#     'scientificNameAuthorship': 'Latreille, 1802',
#     'subphylum': 'Crustacea',
#     'subphylumid': 1066,
#     'summary_stats': {'api': 'https://api.obis.org/statistics/all?taxonid=1071',
#      'datasets': 835,
#      'date_cached': '2019-03-03T13:18:17.609470',
#      'records': 3973340,
#      'species': 24392,
#      'specieslevel': 2888581,
#      'taxa': 24621,
#      'yearrange': [1697, 2018]},
#     'superclass': 'Multicrustacea',
#     'superclassid': 845959,
#     'taxonID': 1071,
#     'taxonRank': 'Class',
#     'taxonomicStatus': 'accepted'},
#    'Maxillopoda': {'api': 'https://api.obis.org/taxon/Maxillopoda',
#     'class': 'Maxillopoda',
#     'classid': 1070,
#     'date_cached': '2019-03-03T13:18:24.432525',
#     'is_marine': True,
#     'kingdom': 'Animalia',
#     'kingdomid': 2,
#     'phylum': 'Arthropoda',
#     'phylumid': 1065,
#     'scientificName': 'Maxillopoda',
#     'scientificNameAuthorship': 'Dahl, 1956',
#     'subphylum': 'Crustacea',
#     'subphylumid': 1066,
#     'taxonID': 1070,
#     'taxonRank': 'Class',
#     'taxonomicStatus': 'unaccepted'},
#    'Merostomata': {'acceptedNameUsage': 'Merostomata',
#     'acceptedNameUsageID': 150507,
#     'api': 'https://api.obis.org/taxon/Merostomata',
#     'class': 'Merostomata',
#     'classid': 150507,
#     'date_cached': '2019-03-03T13:19:26.110489',
#     'kingdom': 'Animalia',
#     'kingdomid': 2,
#     'phylum': 'Arthropoda',
#     'phylumid': 1065,
#     'scientificName': 'Merostomata',
#     'scientificNameAuthorship': 'Woodward, 1866',
#     'subphylum': 'Chelicerata',
#     'subphylumid': 1274,
#     'summary_stats': {'api': 'https://api.obis.org/statistics/all?taxonid=150507',
#      'datasets': 22,
#      'date_cached': '2019-03-03T13:19:26.885813',
#      'records': 6598,
#      'species': 4,
#      'specieslevel': 4376,
#      'taxa': 6,
#      'yearrange': [1904, 2015]},
#     'taxonID': 150507,
#     'taxonRank': 'Class',
#     'taxonomicStatus': 'accepted'},
#    'Ophiuroidea': {'acceptedNameUsage': 'Ophiuroidea',
#     'acceptedNameUsageID': 123084,
#     'api': 'https://api.obis.org/taxon/Ophiuroidea',
#     'class': 'Ophiuroidea',
#     'classid': 123084,
#     'date_cached': '2019-03-03T13:19:36.002122',
#     'is_marine': True,
#     'kingdom': 'Animalia',
#     'kingdomid': 2,
#     'phylum': 'Echinodermata',
#     'phylumid': 1806,
#     'scientificName': 'Ophiuroidea',
#     'scientificNameAuthorship': 'Gray, 1840',
#     'subphylum': 'Asterozoa',
#     'subphylumid': 148743,
#     'summary_stats': {'api': 'https://api.obis.org/statistics/all?taxonid=123084',
#      'datasets': 403,
#      'date_cached': '2019-03-03T13:19:36.923778',
#      'records': 266458,
#      'species': 1607,
#      'specieslevel': 174622,
#      'taxa': 1748,
#      'yearrange': [1828, 2018]},
#     'taxonID': 123084,
#     'taxonRank': 'Class',
#     'taxonomicStatus': 'accepted'},
#    'Palaeonemertea': {'acceptedNameUsage': 'Palaeonemertea',
#     'acceptedNameUsageID': 122307,
#     'api': 'https://api.obis.org/taxon/Palaeonemertea',
#     'class': 'Palaeonemertea',
#     'classid': 122307,
#     'date_cached': '2019-03-03T13:21:04.788868',
#     'is_marine': True,
#     'kingdom': 'Animalia',
#     'kingdomid': 2,
#     'phylum': 'Nemertea',
#     'phylumid': 152391,
#     'scientificName': 'Palaeonemertea',
#     'scientificNameAuthorship': 'Hubrecht, 1879',
#     'summary_stats': {'api': 'https://api.obis.org/statistics/all?taxonid=122307',
#      'datasets': 57,
#      'date_cached': '2019-03-03T13:21:05.603981',
#      'records': 9461,
#      'species': 38,
#      'specieslevel': 5784,
#      'taxa': 45,
#      'yearrange': [1868, 2016]},
#     'taxonID': 122307,
#     'taxonRank': 'Class',
#     'taxonomicStatus': 'accepted'},
#    'Phascolosomatidea': {'acceptedNameUsage': 'Phascolosomatidea',
#     'acceptedNameUsageID': 1295,
#     'api': 'https://api.obis.org/taxon/Phascolosomatidea',
#     'class': 'Phascolosomatidea',
#     'classid': 1295,
#     'date_cached': '2019-03-03T13:21:08.697009',
#     'is_marine': True,
#     'kingdom': 'Animalia',
#     'kingdomid': 2,
#     'phylum': 'Sipuncula',
#     'phylumid': 1268,
#     'scientificName': 'Phascolosomatidea',
#     'summary_stats': {'api': 'https://api.obis.org/statistics/all?taxonid=1295',
#      'datasets': 88,
#      'date_cached': '2019-03-03T13:21:09.503676',
#      'records': 8248,
#      'species': 39,
#      'specieslevel': 6795,
#      'taxa': 55,
#      'yearrange': [1828, 2016]},
#     'taxonID': 1295,
#     'taxonRank': 'Class',
#     'taxonomicStatus': 'accepted'},
#    'Pilidiophora': {'acceptedNameUsage': 'Pilidiophora',
#     'acceptedNameUsageID': 1320351,
#     'api': 'https://api.obis.org/taxon/Pilidiophora',
#     'class': 'Pilidiophora',
#     'classid': 1320351,
#     'date_cached': '2019-03-03T13:21:14.615251',
#     'is_marine': True,
#     'kingdom': 'Animalia',
#     'kingdomid': 2,
#     'phylum': 'Nemertea',
#     'phylumid': 152391,
#     'scientificName': 'Pilidiophora',
#     'scientificNameAuthorship': 'Thollesson & Norenburg, 2003',
#     'summary_stats': {'api': 'https://api.obis.org/statistics/all?taxonid=1320351',
#      'datasets': 68,
#      'date_cached': '2019-03-03T13:21:15.435913',
#      'records': 6460,
#      'species': 44,
#      'specieslevel': 1608,
#      'taxa': 51,
#      'yearrange': [1887, 2017]},
#     'taxonID': 1320351,
#     'taxonRank': 'Class',
#     'taxonomicStatus': 'accepted'},
#    'Polyplacophora': {'acceptedNameUsage': 'Polyplacophora',
#     'acceptedNameUsageID': 55,
#     'api': 'https://api.obis.org/taxon/Polyplacophora',
#     'class': 'Polyplacophora',
#     'classid': 55,
#     'date_cached': '2019-03-03T13:19:32.018120',
#     'is_marine': True,
#     'kingdom': 'Animalia',
#     'kingdomid': 2,
#     'phylum': 'Mollusca',
#     'phylumid': 51,
#     'scientificName': 'Polyplacophora',
#     'scientificNameAuthorship': 'Gray, 1821',
#     'summary_stats': {'api': 'https://api.obis.org/statistics/all?taxonid=55',
#      'datasets': 241,
#      'date_cached': '2019-03-03T13:19:32.828113',
#      'records': 32123,
#      'species': 519,
#      'specieslevel': 25819,
#      'taxa': 573,
#      'yearrange': [1771, 2018]},
#     'taxonID': 55,
#     'taxonRank': 'Class',
#     'taxonomicStatus': 'accepted'},
#    'Priapulida': {'acceptedNameUsage': 'Priapulida',
#     'acceptedNameUsageID': 101063,
#     'api': 'https://api.obis.org/taxon/Priapulida',
#     'class': 'Priapulida',
#     'classid': 101063,
#     'date_cached': '2019-03-03T13:19:58.633073',
#     'is_marine': True,
#     'kingdom': 'Animalia',
#     'kingdomid': 2,
#     'phylum': 'Cephalorhyncha',
#     'phylumid': 22699,
#     'scientificName': 'Priapulida',
#     'scientificNameAuthorship': 'Théel, 1906',
#     'summary_stats': {'api': 'https://api.obis.org/statistics/all?taxonid=101063',
#      'datasets': 110,
#      'date_cached': '2019-03-03T13:19:59.453762',
#      'records': 14798,
#      'species': 9,
#      'specieslevel': 13323,
#      'taxa': 15,
#      'yearrange': [1868, 2017]},
#     'taxonID': 101063,
#     'taxonRank': 'Class',
#     'taxonomicStatus': 'accepted'},
#    'Pycnogonida': {'acceptedNameUsage': 'Pycnogonida',
#     'acceptedNameUsageID': 1302,
#     'api': 'https://api.obis.org/taxon/Pycnogonida',
#     'class': 'Pycnogonida',
#     'classid': 1302,
#     'date_cached': '2019-03-03T13:18:22.786333',
#     'is_marine': True,
#     'kingdom': 'Animalia',
#     'kingdomid': 2,
#     'phylum': 'Arthropoda',
#     'phylumid': 1065,
#     'scientificName': 'Pycnogonida',
#     'scientificNameAuthorship': 'Latreille, 1810',
#     'subphylum': 'Chelicerata',
#     'subphylumid': 1274,
#     'summary_stats': {'api': 'https://api.obis.org/statistics/all?taxonid=1302',
#      'datasets': 236,
#      'date_cached': '2019-03-03T13:18:23.412610',
#      'records': 35774,
#      'species': 1022,
#      'specieslevel': 27893,
#      'taxa': 1118,
#      'yearrange': [1869, 2018]},
#     'taxonID': 1302,
#     'taxonRank': 'Class',
#     'taxonomicStatus': 'accepted'},
#    'Rhabditophora': {'acceptedNameUsage': 'Rhabditophora',
#     'acceptedNameUsageID': 479175,
#     'api': 'https://api.obis.org/taxon/Rhabditophora',
#     'date_cached': '2019-03-03T13:20:00.662210',
#     'is_brackish': True,
#     'is_freshwater': True,
#     'is_marine': True,
#     'is_terrestrial': True,
#     'kingdom': 'Animalia',
#     'kingdomid': 2,
#     'phylum': 'Platyhelminthes',
#     'phylumid': 793,
#     'scientificName': 'Rhabditophora',
#     'scientificNameAuthorship': 'Ehlers, 1985',
#     'subphylum': 'Rhabditophora',
#     'subphylumid': 479175,
#     'summary_stats': {'api': 'https://api.obis.org/statistics/all?taxonid=479175',
#      'datasets': 84,
#      'date_cached': '2019-03-03T13:20:01.499928',
#      'records': 8906,
#      'species': 1831,
#      'specieslevel': 4747,
#      'taxa': 2252,
#      'yearrange': [1903, 2018]},
#     'taxonID': 479175,
#     'taxonRank': 'Subphylum',
#     'taxonomicStatus': 'accepted'},
#    'Rhynchonellata': {'acceptedNameUsage': 'Rhynchonellata',
#     'acceptedNameUsageID': 104020,
#     'api': 'https://api.obis.org/taxon/Rhynchonellata',
#     'class': 'Rhynchonellata',
#     'classid': 104020,
#     'date_cached': '2019-03-03T13:21:10.537381',
#     'is_marine': True,
#     'kingdom': 'Animalia',
#     'kingdomid': 2,
#     'phylum': 'Brachiopoda',
#     'phylumid': 1803,
#     'scientificName': 'Rhynchonellata',
#     'scientificNameAuthorship': 'Williams, Carlson, Brunton, Holmer & Popov, 1996',
#     'subphylum': 'Rhynchonelliformea',
#     'subphylumid': 104018,
#     'summary_stats': {'api': 'https://api.obis.org/statistics/all?taxonid=104020',
#      'datasets': 100,
#      'date_cached': '2019-03-03T13:21:11.543427',
#      'records': 8001,
#      'species': 208,
#      'specieslevel': 7467,
#      'taxa': 253,
#      'yearrange': [1869, 2016]},
#     'taxonID': 104020,
#     'taxonRank': 'Class',
#     'taxonomicStatus': 'accepted'},
#    'Sagittoidea': {'acceptedNameUsage': 'Sagittoidea',
#     'acceptedNameUsageID': 5949,
#     'api': 'https://api.obis.org/taxon/Sagittoidea',
#     'class': 'Sagittoidea',
#     'classid': 5949,
#     'date_cached': '2019-03-03T13:19:38.015123',
#     'is_marine': True,
#     'kingdom': 'Animalia',
#     'kingdomid': 2,
#     'phylum': 'Chaetognatha',
#     'phylumid': 2081,
#     'scientificName': 'Sagittoidea',
#     'summary_stats': {'api': 'https://api.obis.org/statistics/all?taxonid=5949',
#      'datasets': 185,
#      'date_cached': '2019-03-03T13:19:38.971694',
#      'records': 215078,
#      'species': 70,
#      'specieslevel': 147477,
#      'taxa': 90,
#      'yearrange': [1827, 2018]},
#     'taxonID': 5949,
#     'taxonRank': 'Class',
#     'taxonomicStatus': 'accepted'},
#    'Scaphopoda': {'acceptedNameUsage': 'Scaphopoda',
#     'acceptedNameUsageID': 104,
#     'api': 'https://api.obis.org/taxon/Scaphopoda',
#     'class': 'Scaphopoda',
#     'classid': 104,
#     'date_cached': '2019-03-03T13:19:34.044785',
#     'is_marine': True,
#     'kingdom': 'Animalia',
#     'kingdomid': 2,
#     'phylum': 'Mollusca',
#     'phylumid': 51,
#     'scientificName': 'Scaphopoda',
#     'scientificNameAuthorship': 'Bronn, 1862',
#     'summary_stats': {'api': 'https://api.obis.org/statistics/all?taxonid=104',
#      'datasets': 171,
#      'date_cached': '2019-03-03T13:19:34.875952',
#      'records': 20052,
#      'species': 397,
#      'specieslevel': 15069,
#      'taxa': 428,
#      'yearrange': [1869, 2018]},
#     'taxonID': 104,
#     'taxonRank': 'Class',
#     'taxonomicStatus': 'accepted'},
#    'Sipunculidea': {'acceptedNameUsage': 'Sipunculidea',
#     'acceptedNameUsageID': 1296,
#     'api': 'https://api.obis.org/taxon/Sipunculidea',
#     'class': 'Sipunculidea',
#     'classid': 1296,
#     'date_cached': '2019-03-03T13:19:53.112045',
#     'is_marine': True,
#     'kingdom': 'Animalia',
#     'kingdomid': 2,
#     'phylum': 'Sipuncula',
#     'phylumid': 1268,
#     'scientificName': 'Sipunculidea',
#     'summary_stats': {'api': 'https://api.obis.org/statistics/all?taxonid=1296',
#      'datasets': 166,
#      'date_cached': '2019-03-03T13:19:53.687484',
#      'records': 34870,
#      'species': 76,
#      'specieslevel': 26518,
#      'taxa': 109,
#      'yearrange': [1872, 2017]},
#     'taxonID': 1296,
#     'taxonRank': 'Class',
#     'taxonomicStatus': 'accepted'},
#    'Stenolaemata': {'acceptedNameUsage': 'Stenolaemata',
#     'acceptedNameUsageID': 1794,
#     'api': 'https://api.obis.org/taxon/Stenolaemata',
#     'class': 'Stenolaemata',
#     'classid': 1794,
#     'date_cached': '2019-03-03T13:19:56.611082',
#     'is_freshwater': False,
#     'is_marine': True,
#     'is_terrestrial': False,
#     'kingdom': 'Animalia',
#     'kingdomid': 2,
#     'phylum': 'Bryozoa',
#     'phylumid': 146142,
#     'scientificName': 'Stenolaemata',
#     'scientificNameAuthorship': 'Borg, 1926',
#     'summary_stats': {'api': 'https://api.obis.org/statistics/all?taxonid=1794',
#      'datasets': 111,
#      'date_cached': '2019-03-03T13:19:57.404175',
#      'records': 20115,
#      'species': 227,
#      'specieslevel': 11804,
#      'taxa': 303,
#      'yearrange': [1868, 2015]},
#     'taxonID': 1794,
#     'taxonRank': 'Class',
#     'taxonomicStatus': 'accepted'},
#    'Tentaculata': {'acceptedNameUsage': 'Tentaculata',
#     'acceptedNameUsageID': 1249,
#     'api': 'https://api.obis.org/taxon/Tentaculata',
#     'class': 'Tentaculata',
#     'classid': 1249,
#     'date_cached': '2019-03-03T13:19:54.742019',
#     'is_marine': True,
#     'kingdom': 'Animalia',
#     'kingdomid': 2,
#     'phylum': 'Ctenophora',
#     'phylumid': 1248,
#     'scientificName': 'Tentaculata',
#     'scientificNameAuthorship': 'Eschscholtz, 1825',
#     'summary_stats': {'api': 'https://api.obis.org/statistics/all?taxonid=1249',
#      'datasets': 128,
#      'date_cached': '2019-03-03T13:19:55.562321',
#      'records': 20934,
#      'species': 49,
#      'specieslevel': 11430,
#      'taxa': 88,
#      'yearrange': [1871, 2016]},
#     'taxonID': 1249,
#     'taxonRank': 'Class',
#     'taxonomicStatus': 'accepted'},
#    'Turbellaria': {'api': 'https://api.obis.org/taxon/Turbellaria',
#     'class': 'Turbellaria',
#     'classid': 794,
#     'date_cached': '2019-03-03T13:20:02.728986',
#     'is_marine': True,
#     'kingdom': 'Animalia',
#     'kingdomid': 2,
#     'phylum': 'Platyhelminthes',
#     'phylumid': 793,
#     'scientificName': 'Turbellaria',
#     'scientificNameAuthorship': 'Ehrenberg, 1831',
#     'taxonID': 794,
#     'taxonRank': 'Class',
#     'taxonomicStatus': 'unaccepted'}},
#   'obis_worms_taxa_list': ['Hexanauplia',
#    'Malacostraca',
#    'Branchiopoda',
#    'Insecta',
#    'Pycnogonida',
#    'Maxillopoda',
#    'Merostomata',
#    'Gastropoda',
#    'Bivalvia',
#    'Polyplacophora',
#    'Scaphopoda',
#    'Ophiuroidea',
#    'Sagittoidea',
#    'Asteroidea',
#    'Echinoidea',
#    'Clitellata',
#    'Holothuroidea',
#    'Crinoidea',
#    'Chromadorea',
#    'Enoplea',
#    'Sipunculidea',
#    'Tentaculata',
#    'Stenolaemata',
#    'Priapulida',
#    'Rhabditophora',
#    'Turbellaria',
#    'Palaeonemertea',
#    'Enteropneusta',
#    'Phascolosomatidea',
#    'Rhynchonellata',
#    'Hoplonemertea',
#    'Pilidiophora'],
#   'url': ''},
#  'macroalgae': {'label': 'Macroalgal canopy cover and composition',
#   'obis_worms_taxa': {'Charophyceae': {'acceptedNameUsage': 'Charophyceae',
#     'acceptedNameUsageID': 146217,
#     'api': 'https://api.obis.org/taxon/Charophyceae',
#     'class': 'Charophyceae',
#     'classid': 146217,
#     'date_cached': '2019-03-03T13:21:16.664224',
#     'infrakingdom': 'Streptophyta',
#     'infrakingdomids': 536191,
#     'is_marine': True,
#     'kingdom': 'Plantae',
#     'kingdomid': 3,
#     'scientificName': 'Charophyceae',
#     'scientificNameAuthorship': 'Rabenhorst, 1863',
#     'subkingdom': 'Viridiplantae',
#     'subkingdomid': 368663,
#     'summary_stats': {'api': 'https://api.obis.org/statistics/all?taxonid=146217',
#      'datasets': 14,
#      'date_cached': '2019-03-03T13:21:17.313687',
#      'records': 7436,
#      'species': 24,
#      'specieslevel': 5117,
#      'taxa': 32,
#      'yearrange': [1975, 2017]},
#     'taxonID': 146217,
#     'taxonRank': 'Class',
#     'taxonomicStatus': 'accepted'},
#    'Florideophyceae': {'acceptedNameUsage': 'Florideophyceae',
#     'acceptedNameUsageID': 368670,
#     'api': 'https://api.obis.org/taxon/Florideophyceae',
#     'class': 'Florideophyceae',
#     'classid': 368670,
#     'date_cached': '2019-03-03T13:21:18.201657',
#     'is_marine': True,
#     'kingdom': 'Plantae',
#     'kingdomid': 3,
#     'phylum': 'Rhodophyta',
#     'phylumid': 852,
#     'scientificName': 'Florideophyceae',
#     'scientificNameAuthorship': 'Cronquist, 1960',
#     'subdivision': 'Eurhodophytina',
#     'subdivisionid': 493826,
#     'subkingdom': 'Biliphyta',
#     'subkingdomid': 368662,
#     'summary_stats': {'api': 'https://api.obis.org/statistics/all?taxonid=368670',
#      'datasets': 236,
#      'date_cached': '2019-03-03T13:21:18.762433',
#      'records': 556348,
#      'species': 2728,
#      'specieslevel': 421738,
#      'taxa': 3111,
#      'yearrange': [1648, 2018]},
#     'taxonID': 368670,
#     'taxonRank': 'Class',
#     'taxonomicStatus': 'accepted'},
#    'Phaeophyceae': {'acceptedNameUsage': 'Phaeophyceae',
#     'acceptedNameUsageID': 830,
#     'api': 'https://api.obis.org/taxon/Phaeophyceae',
#     'class': 'Phaeophyceae',
#     'classid': 830,
#     'date_cached': '2019-03-03T13:21:19.621370',
#     'infrakingdom': 'Heterokonta',
#     'infrakingdomids': 368898,
#     'infraphylum': 'Limnista',
#     'infraphylumid': 591205,
#     'is_marine': True,
#     'kingdom': 'Chromista',
#     'kingdomid': 7,
#     'phylum': 'Ochrophyta',
#     'phylumid': 345465,
#     'scientificName': 'Phaeophyceae',
#     'scientificNameAuthorship': 'Kjellman, 1891',
#     'subkingdom': 'Harosa',
#     'subkingdomid': 582419,
#     'subphylum': 'Phaeista',
#     'subphylumid': 588641,
#     'summary_stats': {'api': 'https://api.obis.org/statistics/all?taxonid=830',
#      'datasets': 219,
#      'date_cached': '2019-03-03T13:21:20.239013',
#      'records': 357064,
#      'species': 808,
#      'specieslevel': 287124,
#      'taxa': 1040,
#      'yearrange': [1809, 2018]},
#     'superclass': 'Fucistia',
#     'superclassid': 588642,
#     'taxonID': 830,
#     'taxonRank': 'Class',
#     'taxonomicStatus': 'accepted'},
#    'Pyramimonadophyceae': {'acceptedNameUsage': 'Pyramimonadophyceae',
#     'acceptedNameUsageID': 886274,
#     'api': 'https://api.obis.org/taxon/Pyramimonadophyceae',
#     'class': 'Pyramimonadophyceae',
#     'classid': 886274,
#     'date_cached': '2019-03-03T13:21:21.373622',
#     'is_marine': True,
#     'kingdom': 'Plantae',
#     'kingdomid': 3,
#     'scientificName': 'Pyramimonadophyceae',
#     'subkingdom': 'Viridiplantae',
#     'subkingdomid': 368663,
#     'summary_stats': {'api': 'https://api.obis.org/statistics/all?taxonid=886274',
#      'datasets': 109,
#      'date_cached': '2019-03-03T13:21:22.398103',
#      'records': 40477,
#      'species': 33,
#      'specieslevel': 11528,
#      'taxa': 44,
#      'yearrange': [1902, 2016]},
#     'taxonID': 886274,
#     'taxonRank': 'Class',
#     'taxonomicStatus': 'accepted'},
#    'Trebouxiophyceae': {'acceptedNameUsage': 'Trebouxiophyceae',
#     'acceptedNameUsageID': 160573,
#     'api': 'https://api.obis.org/taxon/Trebouxiophyceae',
#     'class': 'Trebouxiophyceae',
#     'classid': 160573,
#     'date_cached': '2019-03-03T13:21:23.409906',
#     'is_marine': True,
#     'kingdom': 'Plantae',
#     'kingdomid': 3,
#     'scientificName': 'Trebouxiophyceae',
#     'scientificNameAuthorship': 'Friedl, 1995',
#     'subkingdom': 'Viridiplantae',
#     'subkingdomid': 368663,
#     'summary_stats': {'api': 'https://api.obis.org/statistics/all?taxonid=160573',
#      'datasets': 83,
#      'date_cached': '2019-03-03T13:21:23.975566',
#      'records': 18231,
#      'species': 97,
#      'specieslevel': 9575,
#      'taxa': 132,
#      'yearrange': [1902, 2016]},
#     'taxonID': 160573,
#     'taxonRank': 'Class',
#     'taxonomicStatus': 'accepted'},
#    'Ulvophyceae': {'acceptedNameUsage': 'Ulvophyceae',
#     'acceptedNameUsageID': 146216,
#     'api': 'https://api.obis.org/taxon/Ulvophyceae',
#     'class': 'Ulvophyceae',
#     'classid': 146216,
#     'date_cached': '2019-03-03T13:21:25.060515',
#     'is_marine': True,
#     'kingdom': 'Plantae',
#     'kingdomid': 3,
#     'scientificName': 'Ulvophyceae',
#     'scientificNameAuthorship': 'K.R. Mattox & K.D. Stewart, 1978',
#     'subkingdom': 'Viridiplantae',
#     'subkingdomid': 368663,
#     'summary_stats': {'api': 'https://api.obis.org/statistics/all?taxonid=146216',
#      'datasets': 216,
#      'date_cached': '2019-03-03T13:21:25.879083',
#      'records': 220235,
#      'species': 672,
#      'specieslevel': 135777,
#      'taxa': 870,
#      'yearrange': [1753, 2018]},
#     'taxonID': 146216,
#     'taxonRank': 'Class',
#     'taxonomicStatus': 'accepted'}},
#   'obis_worms_taxa_list': ['Charophyceae',
#    'Florideophyceae',
#    'Phaeophyceae',
#    'Pyramimonadophyceae',
#    'Trebouxiophyceae',
#    'Ulvophyceae'],
#   'url': 'http://www.goosocean.org/index.php?option=com_oe&task=viewDocumentRecord&docID=17515'},
#  'mangroves': {'label': 'Mangrove cover and composition',
#   'obis_worms_taxa': {'Acanthaceae': {'acceptedNameUsage': 'Acanthaceae',
#     'acceptedNameUsageID': 344737,
#     'api': 'https://api.obis.org/taxon/Acanthaceae',
#     'class': 'Magnoliopsida',
#     'classid': 182757,
#     'date_cached': '2019-03-03T13:21:30.827616',
#     'family': 'Acanthaceae',
#     'familyid': 344737,
#     'infrakingdom': 'Streptophyta',
#     'infrakingdomids': 536191,
#     'kingdom': 'Plantae',
#     'kingdomid': 3,
#     'order': 'Lamiales',
#     'orderid': 234498,
#     'scientificName': 'Acanthaceae',
#     'subkingdom': 'Viridiplantae',
#     'subkingdomid': 368663,
#     'summary_stats': {'api': 'https://api.obis.org/statistics/all?taxonid=344737',
#      'datasets': 23,
#      'date_cached': '2019-03-03T13:21:31.623348',
#      'records': 705,
#      'species': 6,
#      'specieslevel': 696,
#      'taxa': 8,
#      'yearrange': [1899, 2018]},
#     'superorder': 'Asteranae',
#     'superorderid': 449896,
#     'taxonID': 344737,
#     'taxonRank': 'Family',
#     'taxonomicStatus': 'accepted'},
#    'Arecaceae': {'acceptedNameUsage': 'Arecaceae',
#     'acceptedNameUsageID': 234449,
#     'api': 'https://api.obis.org/taxon/Arecaceae',
#     'class': 'Magnoliopsida',
#     'classid': 182757,
#     'date_cached': '2019-03-03T13:21:40.842037',
#     'family': 'Arecaceae',
#     'familyid': 234449,
#     'infrakingdom': 'Streptophyta',
#     'infrakingdomids': 536191,
#     'is_marine': True,
#     'kingdom': 'Plantae',
#     'kingdomid': 3,
#     'order': 'Arecales',
#     'orderid': 234448,
#     'scientificName': 'Arecaceae',
#     'subkingdom': 'Viridiplantae',
#     'subkingdomid': 368663,
#     'summary_stats': {'api': 'https://api.obis.org/statistics/all?taxonid=234449',
#      'datasets': 6,
#      'date_cached': '2019-03-03T13:21:41.498936',
#      'records': 13,
#      'species': 2,
#      'specieslevel': 12,
#      'taxa': 3,
#      'yearrange': [1990, 2015]},
#     'superorder': 'Lilianae',
#     'superorderid': 449895,
#     'taxonID': 234449,
#     'taxonRank': 'Family',
#     'taxonomicStatus': 'accepted'},
#    'Combretaceae': {'acceptedNameUsage': 'Combretaceae',
#     'acceptedNameUsageID': 235048,
#     'api': 'https://api.obis.org/taxon/Combretaceae',
#     'class': 'Magnoliopsida',
#     'classid': 182757,
#     'date_cached': '2019-03-03T13:21:44.110292',
#     'family': 'Combretaceae',
#     'familyid': 235048,
#     'infrakingdom': 'Streptophyta',
#     'infrakingdomids': 536191,
#     'is_marine': True,
#     'kingdom': 'Plantae',
#     'kingdomid': 3,
#     'order': 'Myrtales',
#     'orderid': 234500,
#     'scientificName': 'Combretaceae',
#     'subkingdom': 'Viridiplantae',
#     'subkingdomid': 368663,
#     'summary_stats': {'api': 'https://api.obis.org/statistics/all?taxonid=235048',
#      'datasets': 14,
#      'date_cached': '2019-03-03T13:21:44.926792',
#      'records': 515,
#      'species': 6,
#      'specieslevel': 515,
#      'taxa': 6,
#      'yearrange': [1969, 2017]},
#     'superorder': 'Rosanae',
#     'superorderid': 449897,
#     'taxonID': 235048,
#     'taxonRank': 'Family',
#     'taxonomicStatus': 'accepted'},
#    'Euphorbiaceae': {'acceptedNameUsage': 'Euphorbiaceae',
#     'acceptedNameUsageID': 235055,
#     'api': 'https://api.obis.org/taxon/Euphorbiaceae',
#     'class': 'Magnoliopsida',
#     'classid': 182757,
#     'date_cached': '2019-03-03T13:21:36.732671',
#     'family': 'Euphorbiaceae',
#     'familyid': 235055,
#     'infrakingdom': 'Streptophyta',
#     'infrakingdomids': 536191,
#     'is_marine': True,
#     'kingdom': 'Plantae',
#     'kingdomid': 3,
#     'order': 'Malpighiales',
#     'orderid': 413964,
#     'scientificName': 'Euphorbiaceae',
#     'subkingdom': 'Viridiplantae',
#     'subkingdomid': 368663,
#     'summary_stats': {'api': 'https://api.obis.org/statistics/all?taxonid=235055',
#      'datasets': 8,
#      'date_cached': '2019-03-03T13:21:37.758885',
#      'records': 53,
#      'species': 8,
#      'specieslevel': 47,
#      'taxa': 9,
#      'yearrange': [1964, 2015]},
#     'superorder': 'Rosanae',
#     'superorderid': 449897,
#     'taxonID': 235055,
#     'taxonRank': 'Family',
#     'taxonomicStatus': 'accepted'},
#    'Lythraceae': {'acceptedNameUsage': 'Lythraceae',
#     'acceptedNameUsageID': 235059,
#     'api': 'https://api.obis.org/taxon/Lythraceae',
#     'class': 'Magnoliopsida',
#     'classid': 182757,
#     'date_cached': '2019-03-03T13:21:38.990309',
#     'family': 'Lythraceae',
#     'familyid': 235059,
#     'infrakingdom': 'Streptophyta',
#     'infrakingdomids': 536191,
#     'is_marine': True,
#     'kingdom': 'Plantae',
#     'kingdomid': 3,
#     'order': 'Myrtales',
#     'orderid': 234500,
#     'scientificName': 'Lythraceae',
#     'subkingdom': 'Viridiplantae',
#     'subkingdomid': 368663,
#     'summary_stats': {'api': 'https://api.obis.org/statistics/all?taxonid=235059',
#      'datasets': 13,
#      'date_cached': '2019-03-03T13:21:39.814666',
#      'records': 391,
#      'species': 6,
#      'specieslevel': 391,
#      'taxa': 6,
#      'yearrange': [1816, 2016]},
#     'superorder': 'Rosanae',
#     'superorderid': 449897,
#     'taxonID': 235059,
#     'taxonRank': 'Family',
#     'taxonomicStatus': 'accepted'},
#    'Malvaceae': {'acceptedNameUsage': 'Malvaceae',
#     'acceptedNameUsageID': 413963,
#     'api': 'https://api.obis.org/taxon/Malvaceae',
#     'class': 'Magnoliopsida',
#     'classid': 182757,
#     'date_cached': '2019-03-03T13:21:42.468706',
#     'family': 'Malvaceae',
#     'familyid': 413963,
#     'infrakingdom': 'Streptophyta',
#     'infrakingdomids': 536191,
#     'kingdom': 'Plantae',
#     'kingdomid': 3,
#     'order': 'Malvales',
#     'orderid': 234499,
#     'scientificName': 'Malvaceae',
#     'subkingdom': 'Viridiplantae',
#     'subkingdomid': 368663,
# ...
#     'infrakingdomids': 536191,
#     'is_marine': True,
#     'kingdom': 'Plantae',
#     'kingdomid': 3,
#     'order': 'Alismatales',
#     'orderid': 153491,
#     'scientificName': 'Hydrocharitaceae',
#     'scientificNameAuthorship': 'Jussieu',
#     'subkingdom': 'Viridiplantae',
#     'subkingdomid': 368663,
#     'summary_stats': {'api': 'https://api.obis.org/statistics/all?taxonid=143751',
#      'datasets': 56,
#      'date_cached': '2019-03-03T13:23:00.294721',
#      'records': 500892,
#      'species': 21,
#      'specieslevel': 498867,
#      'taxa': 26,
#      'yearrange': [1958, 2018]},
#     'superorder': 'Lilianae',
#     'superorderid': 449895,
#     'taxonID': 143751,
#     'taxonRank': 'Family',
#     'taxonomicStatus': 'accepted'},
#    'Posidoniaceae': {'acceptedNameUsage': 'Posidoniaceae',
#     'acceptedNameUsageID': 143769,
#     'api': 'https://api.obis.org/taxon/Posidoniaceae',
#     'class': 'Magnoliopsida',
#     'classid': 182757,
#     'date_cached': '2019-03-03T13:22:55.379040',
#     'family': 'Posidoniaceae',
#     'familyid': 143769,
#     'infrakingdom': 'Streptophyta',
#     'infrakingdomids': 536191,
#     'is_marine': True,
#     'kingdom': 'Plantae',
#     'kingdomid': 3,
#     'order': 'Alismatales',
#     'orderid': 153491,
#     'scientificName': 'Posidoniaceae',
#     'scientificNameAuthorship': 'Lotsy',
#     'subkingdom': 'Viridiplantae',
#     'subkingdomid': 368663,
#     'summary_stats': {'api': 'https://api.obis.org/statistics/all?taxonid=143769',
#      'datasets': 15,
#      'date_cached': '2019-03-03T13:22:56.197968',
#      'records': 603,
#      'species': 7,
#      'specieslevel': 600,
#      'taxa': 8,
#      'yearrange': [1983, 2017]},
#     'superorder': 'Lilianae',
#     'superorderid': 449895,
#     'taxonID': 143769,
#     'taxonRank': 'Family',
#     'taxonomicStatus': 'accepted'},
#    'Zosteraceae': {'acceptedNameUsage': 'Zosteraceae',
#     'acceptedNameUsageID': 143770,
#     'api': 'https://api.obis.org/taxon/Zosteraceae',
#     'class': 'Magnoliopsida',
#     'classid': 182757,
#     'date_cached': '2019-03-03T13:22:57.427058',
#     'family': 'Zosteraceae',
#     'familyid': 143770,
#     'infrakingdom': 'Streptophyta',
#     'infrakingdomids': 536191,
#     'is_marine': True,
#     'kingdom': 'Plantae',
#     'kingdomid': 3,
#     'order': 'Alismatales',
#     'orderid': 153491,
#     'scientificName': 'Zosteraceae',
#     'scientificNameAuthorship': 'Dumortier',
#     'subkingdom': 'Viridiplantae',
#     'subkingdomid': 368663,
#     'summary_stats': {'api': 'https://api.obis.org/statistics/all?taxonid=143770',
#      'datasets': 52,
#      'date_cached': '2019-03-03T13:22:58.222116',
#      'records': 82163,
#      'species': 12,
#      'specieslevel': 80813,
#      'taxa': 14,
#      'yearrange': [1897, 2017]},
#     'superorder': 'Lilianae',
#     'superorderid': 449895,
#     'taxonID': 143770,
#     'taxonRank': 'Family',
#     'taxonomicStatus': 'accepted'}},
#   'obis_worms_taxa_list': ['Posidoniaceae',
#    'Zosteraceae',
#    'Hydrocharitaceae',
#    'Cymodoceaceae'],
#   'url': 'http://www.goosocean.org/index.php?option=com_oe&task=viewDocumentRecord&docID=17513'},
#  'turtles, birds, mammals': {'label': 'Marine turtles, birds, mammals abundance and distribution',
#   'obis_worms_taxa': {'Aves': {'acceptedNameUsage': 'Aves',
#     'acceptedNameUsageID': 1836,
#     'api': 'https://api.obis.org/taxon/Aves',
#     'class': 'Aves',
#     'classid': 1836,
#     'date_cached': '2019-03-03T13:23:03.366894',
#     'is_marine': True,
#     'kingdom': 'Animalia',
#     'kingdomid': 2,
#     'phylum': 'Chordata',
#     'phylumid': 1821,
#     'scientificName': 'Aves',
#     'subphylum': 'Vertebrata',
#     'subphylumid': 146419,
#     'summary_stats': {'api': 'https://api.obis.org/statistics/all?taxonid=1836',
#      'datasets': 239,
#      'date_cached': '2019-03-03T13:23:04.186609',
#      'records': 4452176,
#      'species': 853,
#      'specieslevel': 3955082,
#      'taxa': 1040,
#      'yearrange': [1758, 2018]},
#     'superclass': 'Tetrapoda',
#     'superclassid': 1831,
#     'taxonID': 1836,
#     'taxonRank': 'Class',
#     'taxonomicStatus': 'accepted'},
#    'Mammalia': {'acceptedNameUsage': 'Mammalia',
#     'acceptedNameUsageID': 1837,
#     'api': 'https://api.obis.org/taxon/Mammalia',
#     'class': 'Mammalia',
#     'classid': 1837,
#     'date_cached': '2019-03-03T13:23:05.413911',
#     'is_marine': True,
#     'kingdom': 'Animalia',
#     'kingdomid': 2,
#     'phylum': 'Chordata',
#     'phylumid': 1821,
#     'scientificName': 'Mammalia',
#     'scientificNameAuthorship': 'Linnaeus, 1758',
#     'subphylum': 'Vertebrata',
#     'subphylumid': 146419,
#     'summary_stats': {'api': 'https://api.obis.org/statistics/all?taxonid=1837',
#      'datasets': 678,
#      'date_cached': '2019-03-03T13:23:06.193047',
#      'records': 1224083,
#      'species': 131,
#      'specieslevel': 1131022,
#      'taxa': 191,
#      'yearrange': [1520, 2019]},
#     'superclass': 'Tetrapoda',
#     'superclassid': 1831,
#     'taxonID': 1837,
#     'taxonRank': 'Class',
#     'taxonomicStatus': 'accepted'}},
#   'obis_worms_taxa_list': ['Aves', 'Mammalia'],
#   'url': 'http://www.goosocean.org/index.php?option=com_oe&task=viewDocumentRecord&docID=17511'},
#  'zooplankton': {'label': 'Zooplankton biomass and diversity',
#   'obis_worms_taxa': {'Appendicularia': {'acceptedNameUsage': 'Appendicularia',
#     'acceptedNameUsageID': 146421,
#     'api': 'https://api.obis.org/taxon/Appendicularia',
#     'class': 'Appendicularia',
#     'classid': 146421,
#     'date_cached': '2019-03-03T13:23:28.149142',
#     'is_marine': True,
#     'kingdom': 'Animalia',
#     'kingdomid': 2,
#     'phylum': 'Chordata',
#     'phylumid': 1821,
#     'scientificName': 'Appendicularia',
#     'subphylum': 'Tunicata',
#     'subphylumid': 146420,
#     'summary_stats': {'api': 'https://api.obis.org/statistics/all?taxonid=146421',
#      'datasets': 174,
#      'date_cached': '2019-03-03T13:23:28.967096',
#      'records': 159655,
#      'species': 46,
#      'specieslevel': 23297,
#      'taxa': 63,
#      'yearrange': [1854, 2018]},
#     'taxonID': 146421,
#     'taxonRank': 'Class',
#     'taxonomicStatus': 'accepted'},
#    'Cephalopoda': {'acceptedNameUsage': 'Cephalopoda',
#     'acceptedNameUsageID': 11707,
#     'api': 'https://api.obis.org/taxon/Cephalopoda',
#     'class': 'Cephalopoda',
#     'classid': 11707,
#     'date_cached': '2019-03-03T13:23:24.562626',
#     'is_marine': True,
#     'kingdom': 'Animalia',
#     'kingdomid': 2,
#     'phylum': 'Mollusca',
#     'phylumid': 51,
#     'scientificName': 'Cephalopoda',
#     'scientificNameAuthorship': 'Cuvier, 1795',
#     'summary_stats': {'api': 'https://api.obis.org/statistics/all?taxonid=11707',
#      'datasets': 335,
#      'date_cached': '2019-03-03T13:23:25.167562',
#      'records': 664517,
#      'species': 767,
#      'specieslevel': 571836,
#      'taxa': 870,
#      'yearrange': [1792, 2018]},
#     'taxonID': 11707,
#     'taxonRank': 'Class',
#     'taxonomicStatus': 'accepted'},
#    'Choanoflagellatea': {'acceptedNameUsage': 'Choanoflagellatea',
#     'acceptedNameUsageID': 580116,
#     'api': 'https://api.obis.org/taxon/Choanoflagellatea',
#     'class': 'Choanoflagellatea',
#     'classid': 580116,
#     'date_cached': '2019-03-03T13:23:11.557860',
#     'is_marine': True,
#     'kingdom': 'Protozoa',
#     'kingdomid': 5,
#     'phylum': 'Choanozoa',
#     'phylumid': 562870,
#     'scientificName': 'Choanoflagellatea',
#     'subkingdom': 'Sarcomastigota',
#     'subkingdomid': 582160,
#     'subphylum': 'Choanofila',
#     'subphylumid': 562871,
#     'summary_stats': {'api': 'https://api.obis.org/statistics/all?taxonid=580116',
#      'datasets': 55,
#      'date_cached': '2019-03-03T13:23:12.375831',
#      'records': 26140,
#      'species': 84,
#      'specieslevel': 21137,
#      'taxa': 102,
#      'yearrange': [1861, 2016]},
#     'taxonID': 580116,
#     'taxonRank': 'Class',
#     'taxonomicStatus': 'accepted'},
#    'Ebriophyceae': {'acceptedNameUsage': 'Ebriophyceae',
#     'acceptedNameUsageID': 599640,
#     'api': 'https://api.obis.org/taxon/Ebriophyceae',
#     'class': 'Ebriophyceae',
#     'classid': 599640,
#     'date_cached': '2019-03-03T13:23:09.342072',
#     'kingdom': 'Protozoa',
#     'kingdomid': 5,
#     'scientificName': 'Ebriophyceae',
#     'subkingdom': 'Protozoa incertae sedis',
#     'subkingdomid': 22718,
#     'summary_stats': {'api': 'https://api.obis.org/statistics/all?taxonid=599640',
#      'datasets': 106,
#      'date_cached': '2019-03-03T13:23:10.329789',
#      'records': 18454,
#      'species': 3,
#      'specieslevel': 16490,
#      'taxa': 7,
#      'yearrange': [1903, 2016]},
#     'taxonID': 599640,
#     'taxonRank': 'Class',
#     'taxonomicStatus': 'accepted'},
#    'Euglenoidea': {'acceptedNameUsage': 'Euglenoidea',
#     'acceptedNameUsageID': 582177,
#     'api': 'https://api.obis.org/taxon/Euglenoidea',
#     'class': 'Euglenoidea',
#     'classid': 582177,
#     'date_cached': '2019-03-03T13:23:07.463148',
#     'infrakingdom': 'Euglenozoa',
#     'infrakingdomids': 582161,
#     'kingdom': 'Protozoa',
#     'kingdomid': 5,
#     'phylum': 'Euglenozoa',
#     'phylumid': 536202,
#     'scientificName': 'Euglenoidea',
#     'subkingdom': 'Eozoa',
#     'subkingdomid': 582159,
#     'summary_stats': {'api': 'https://api.obis.org/statistics/all?taxonid=582177',
#      'datasets': 110,
#      'date_cached': '2019-03-03T13:23:08.264506',
#      'records': 42614,
#      'species': 162,
#      'specieslevel': 11107,
#      'taxa': 193,
#      'yearrange': [1903, 2016]},
#     'taxonID': 582177,
#     'taxonRank': 'Class',
#     'taxonomicStatus': 'accepted'},
#    'Hydrozoa': {'acceptedNameUsage': 'Hydrozoa',
#     'acceptedNameUsageID': 1337,
#     'api': 'https://api.obis.org/taxon/Hydrozoa',
#     'class': 'Hydrozoa',
#     'classid': 1337,
#     'date_cached': '2019-03-03T13:23:19.549172',
#     'is_brackish': True,
#     'is_freshwater': True,
#     'is_marine': True,
#     'is_terrestrial': False,
#     'kingdom': 'Animalia',
#     'kingdomid': 2,
#     'phylum': 'Cnidaria',
#     'phylumid': 1267,
#     'scientificName': 'Hydrozoa',
#     'scientificNameAuthorship': 'Owen, 1843',
#     'summary_stats': {'api': 'https://api.obis.org/statistics/all?taxonid=1337',
#      'datasets': 467,
#      'date_cached': '2019-03-03T13:23:20.240893',
#      'records': 388001,
#      'species': 2212,
#      'specieslevel': 164976,
#      'taxa': 2703,
#      'yearrange': [1758, 2018]},
#     'taxonID': 1337,
#     'taxonRank': 'Class',
#     'taxonomicStatus': 'accepted'},
#    'Leptocardii': {'acceptedNameUsage': 'Leptocardii',
#     'acceptedNameUsageID': 104897,
#     'api': 'https://api.obis.org/taxon/Leptocardii',
#     'class': 'Leptocardii',
#     'classid': 104897,
#     'date_cached': '2019-03-03T13:23:13.605015',
#     'is_marine': True,
#     'kingdom': 'Animalia',
#     'kingdomid': 2,
#     'phylum': 'Chordata',
#     'phylumid': 1821,
#     'scientificName': 'Leptocardii',
#     'subphylum': 'Cephalochordata',
#     'subphylumid': 1824,
#     'summary_stats': {'api': 'https://api.obis.org/statistics/all?taxonid=104897',
#      'datasets': 130,
#      'date_cached': '2019-03-03T13:23:14.427026',
#      'records': 10728,
#      'species': 23,
#      'specieslevel': 4914,
#      'taxa': 26,
#      'yearrange': [1778, 2016]},
#     'taxonID': 104897,
#     'taxonRank': 'Class',
#     'taxonomicStatus': 'accepted'},
#    'Monothalamea': {'acceptedNameUsage': 'Monothalamea',
#     'acceptedNameUsageID': 744106,
#     'api': 'https://api.obis.org/taxon/Monothalamea',
#     'class': 'Monothalamea',
#     'classid': 744106,
#     'date_cached': '2019-03-03T13:23:15.655193',
#     'infrakingdom': 'Rhizaria',
#     'infrakingdomids': 582420,
#     'kingdom': 'Chromista',
#     'kingdomid': 7,
#     'phylum': 'Foraminifera',
#     'phylumid': 1410,
#     'scientificName': 'Monothalamea',
#     'scientificNameAuthorship': 'Haeckel, 1862 (as emended by Pawlowski et al., 2013)',
#     'subkingdom': 'Harosa',
#     'subkingdomid': 582419,
#     'summary_stats': {'api': 'https://api.obis.org/statistics/all?taxonid=744106',
#      'datasets': 90,
#      'date_cached': '2019-03-03T13:23:16.472138',
#      'records': 18510,
#      'species': 214,
#      'specieslevel': 12671,
#      'taxa': 283,
#      'yearrange': [1872, 2015]},
#     'taxonID': 744106,
#     'taxonRank': 'Class',
#     'taxonomicStatus': 'accepted'},
#    'Ostracoda': {'acceptedNameUsage': 'Ostracoda',
#     'acceptedNameUsageID': 1078,
#     'api': 'https://api.obis.org/taxon/Ostracoda',
#     'class': 'Ostracoda',
#     'classid': 1078,
#     'date_cached': '2019-03-03T13:23:26.146309',
#     'is_brackish': True,
#     'is_freshwater': True,
#     'is_marine': True,
#     'is_terrestrial': True,
#     'kingdom': 'Animalia',
#     'kingdomid': 2,
#     'phylum': 'Arthropoda',
#     'phylumid': 1065,
#     'scientificName': 'Ostracoda',
#     'scientificNameAuthorship': 'Latreille, 1802',
#     'subphylum': 'Crustacea',
#     'subphylumid': 1066,
#     'summary_stats': {'api': 'https://api.obis.org/statistics/all?taxonid=1078',
#      'datasets': 327,
#      'date_cached': '2019-03-03T13:23:26.919364',
#      'records': 195694,
#      'species': 2208,
#      'specieslevel': 99848,
#      'taxa': 2723,
#      'yearrange': [1849, 2018]},
#     'superclass': 'Oligostraca',
#     'superclassid': 845957,
#     'taxonID': 1078,
#     'taxonRank': 'Class',
#     'taxonomicStatus': 'accepted'},
#    'Polychaeta': {'acceptedNameUsage': 'Polychaeta',
#     'acceptedNameUsageID': 883,
#     'api': 'https://api.obis.org/taxon/Polychaeta',
#     'class': 'Polychaeta',
#     'classid': 883,
#     'date_cached': '2019-03-03T13:23:23.146306',
#     'is_brackish': True,
#     'is_freshwater': True,
#     'is_marine': True,
#     'is_terrestrial': True,
#     'kingdom': 'Animalia',
#     'kingdomid': 2,
#     'phylum': 'Annelida',
#     'phylumid': 882,
#     'scientificName': 'Polychaeta',
#     'scientificNameAuthorship': 'Grube, 1850',
#     'summary_stats': {'api': 'https://api.obis.org/statistics/all?taxonid=883',
#      'datasets': 635,
#      'date_cached': '2019-03-03T13:23:23.726026',
#      'records': 2667261,
#      'species': 7808,
#      'specieslevel': 2007940,
#      'taxa': 8960,
#      'yearrange': [1761, 2018]},
#     'taxonID': 883,
#     'taxonRank': 'Class',
#     'taxonomicStatus': 'accepted'},
#    'Scyphozoa': {'acceptedNameUsage': 'Scyphozoa',
#     'acceptedNameUsageID': 135220,
#     'api': 'https://api.obis.org/taxon/Scyphozoa',
#     'class': 'Scyphozoa',
#     'classid': 135220,
#     'date_cached': '2019-03-03T13:23:21.596596',
#     'is_brackish': True,
#     'is_freshwater': False,
#     'is_marine': True,
#     'is_terrestrial': False,
#     'kingdom': 'Animalia',
#     'kingdomid': 2,
#     'phylum': 'Cnidaria',
#     'phylumid': 1267,
#     'scientificName': 'Scyphozoa',
#     'scientificNameAuthorship': 'Goette, 1887',
#     'summary_stats': {'api': 'https://api.obis.org/statistics/all?taxonid=135220',
#      'datasets': 244,
#      'date_cached': '2019-03-03T13:23:22.283211',
#      'records': 52392,
#      'species': 113,
#      'specieslevel': 26076,
#      'taxa': 153,
#      'yearrange': [1774, 2018]},
#     'taxonID': 135220,
#     'taxonRank': 'Class',
#     'taxonomicStatus': 'accepted'},
#    'Thaliacea': {'acceptedNameUsage': 'Thaliacea',
#     'acceptedNameUsageID': 22626,
#     'api': 'https://api.obis.org/taxon/Thaliacea',
#     'class': 'Thaliacea',
#     'classid': 22626,
#     'date_cached': '2019-03-03T13:23:17.702955',
#     'is_brackish': False,
#     'is_freshwater': False,
#     'is_marine': True,
#     'is_terrestrial': False,
#     'kingdom': 'Animalia',
#     'kingdomid': 2,
#     'phylum': 'Chordata',
#     'phylumid': 1821,
#     'scientificName': 'Thaliacea',
#     'scientificNameAuthorship': 'Van der Haeven, 1850',
#     'subphylum': 'Tunicata',
#     'subphylumid': 146420,
#     'summary_stats': {'api': 'https://api.obis.org/statistics/all?taxonid=22626',
#      'datasets': 148,
#      'date_cached': '2019-03-03T13:23:18.531558',
#      'records': 66177,
#      'species': 68,
#      'specieslevel': 12952,
#      'taxa': 92,
#      'yearrange': [1774, 2018]},
#     'taxonID': 22626,
#     'taxonRank': 'Class',
#     'taxonomicStatus': 'accepted'}},
#   'obis_worms_taxa_list': ['Euglenoidea',
#    'Ebriophyceae',
#    'Choanoflagellatea',
#    'Leptocardii',
#    'Monothalamea',
#    'Thaliacea',
#    'Hydrozoa',
#    'Scyphozoa',
#    'Polychaeta',
#    'Cephalopoda',
#    'Ostracoda',
#    'Appendicularia'],
#   'url': 'http://www.goosocean.org/index.php?option=com_oe&task=viewDocumentRecord&docID=17509'}}

# %%
# Write out the new data to a JSON file
with open('eov_packet.json', 'w') as f:
    f.write(json.dumps(new_eov_doc, indent=4))
