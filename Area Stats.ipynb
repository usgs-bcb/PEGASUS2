# %%
import requests
from IPython.display import display
import pegasus_functions as pf
from datetime import datetime

# %%
eov_packet = pf.get_eov_packet()
obis_areas = requests.get("https://api.obis.org/area").json()

# %%
area_stats_cache = list()

for i_eov,eov in enumerate(eov_packet):
    if i_eov > 0:
        break

    for i_area,area in enumerate(obis_areas["results"]):
        if i_area > 4:
            break
        
        area_stats = pf.summary_stats_by_aphiaids(pf.get_worms_info(eov["name"])["valid_aphiaids"], summary_type="statistics/all", area_id=area["id"])

        for k, v in area.items():
            area_stats[f"area_{k}"] = v
        for k, v in eov.items():
            area_stats[f"eov_{k}"] = v

        area_stats["area_records_per_year"] = pf.summary_stats_by_aphiaids(pf.get_worms_info(eov["name"])["valid_aphiaids"], summary_type="statistics/years", area_id=area["id"])
        area_stats["date_cached"] = datetime.utcnow().isoformat()

        area_stats_cache.append(area_stats)

display(area_stats_cache)
print(len(area_stats_cache))
# Out:
# [{'area_id': '10001',
#   'area_name': '2les des Sept Frbres et Godorya (Seven Brothers Islands and Godorya',
#   'area_records_per_year': [],
#   'area_type': 'ebsa',
#   'datasets': 0,
#   'date_cached': '2019-02-28T23:21:15.104319',
#   'eov_label': 'Phytoplankton biomass and diversity',
#   'eov_name': 'phytoplankton',
#   'eov_taxonomic_names': ['Chlorophyceae',
#    'Chrysophyceae',
#    'Cryptophyceae',
#    'Cyanophyceae',
#    'Diatomophyceae',
#    'Dictyochophyceae',
#    'Dinophyceae',
#    'Euglenophyceae',
#    'Eustigmatophyceae',
#    'Micromonadophyceae',
#    'Pedinophyceae',
#    'Prasinophyceae',
#    'Prymnesiophyceae',
#    'Raphidophyceae',
#    'Rhodophyceae',
#    'Tribophyceae'],
#   'eov_url': 'http://www.goosocean.org/index.php?option=com_oe&task=viewDocumentRecord&docID=17507',
#   'records': 0,
#   'species': 0,
#   'specieslevel': 0,
#   'taxa': 0,
#   'yearrange': [None, None]},
#  {'area_id': '1',
#   'area_name': 'ABNJ',
#   'area_records_per_year': [{'records': 50,
#     'species': 32,
#     'taxa': 32,
#     'year': 1900},
#    {'records': 84, 'species': 33, 'taxa': 33, 'year': 1903},
#    {'records': 239, 'species': 31, 'taxa': 31, 'year': 1904},
#    {'records': 6, 'species': 6, 'taxa': 6, 'year': 1905},
#    {'records': 8, 'species': 8, 'taxa': 8, 'year': 1906},
#    {'records': 9, 'species': 6, 'taxa': 6, 'year': 1927},
#    {'records': 5, 'species': 5, 'taxa': 5, 'year': 1928},
#    {'records': 392, 'species': 62, 'taxa': 73, 'year': 1929},
#    {'records': 995, 'species': 111, 'taxa': 125, 'year': 1930},
#    {'records': 1408, 'species': 113, 'taxa': 127, 'year': 1931},
#    {'records': 47, 'species': 17, 'taxa': 17, 'year': 1934},
#    {'records': 34, 'species': 16, 'taxa': 16, 'year': 1935},
#    {'records': 47, 'species': 23, 'taxa': 26, 'year': 1938},
#    {'records': 250, 'species': 42, 'taxa': 45, 'year': 1939},
#    {'records': 152, 'species': 33, 'taxa': 41, 'year': 1946},
#    {'records': 459, 'species': 52, 'taxa': 64, 'year': 1947},
#    {'records': 635, 'species': 25, 'taxa': 31, 'year': 1948},
#    {'records': 466, 'species': 25, 'taxa': 31, 'year': 1949},
#    {'records': 445, 'species': 20, 'taxa': 26, 'year': 1950},
#    {'records': 482, 'species': 27, 'taxa': 34, 'year': 1951},
#    {'records': 958, 'species': 28, 'taxa': 37, 'year': 1952},
#    {'records': 799, 'species': 27, 'taxa': 36, 'year': 1953},
#    {'records': 4619, 'species': 49, 'taxa': 58, 'year': 1954},
#    {'records': 1462, 'species': 34, 'taxa': 43, 'year': 1955},
#    {'records': 1105, 'species': 33, 'taxa': 45, 'year': 1956},
#    {'records': 2674, 'species': 106, 'taxa': 121, 'year': 1957},
#    {'records': 1128, 'species': 35, 'taxa': 44, 'year': 1958},
#    {'records': 2335, 'species': 36, 'taxa': 46, 'year': 1959},
#    {'records': 1990, 'species': 225, 'taxa': 245, 'year': 1960},
#    {'records': 3358, 'species': 180, 'taxa': 197, 'year': 1961},
#    {'records': 3301, 'species': 176, 'taxa': 196, 'year': 1962},
#    {'records': 2078, 'species': 56, 'taxa': 71, 'year': 1963},
#    {'records': 3933, 'species': 73, 'taxa': 95, 'year': 1964},
#    {'records': 4334, 'species': 66, 'taxa': 100, 'year': 1965},
#    {'records': 3306, 'species': 85, 'taxa': 111, 'year': 1966},
#    {'records': 4048, 'species': 47, 'taxa': 69, 'year': 1967},
#    {'records': 3887, 'species': 50, 'taxa': 72, 'year': 1968},
#    {'records': 3641, 'species': 86, 'taxa': 120, 'year': 1969},
#    {'records': 4757, 'species': 96, 'taxa': 132, 'year': 1970},
#    {'records': 4442, 'species': 83, 'taxa': 119, 'year': 1971},
#    {'records': 6077, 'species': 123, 'taxa': 162, 'year': 1972},
#    {'records': 3462, 'species': 98, 'taxa': 129, 'year': 1973},
#    {'records': 4297, 'species': 104, 'taxa': 134, 'year': 1974},
#    {'records': 4040, 'species': 99, 'taxa': 131, 'year': 1975},
#    {'records': 2519, 'species': 106, 'taxa': 138, 'year': 1976},
#    {'records': 5594, 'species': 146, 'taxa': 180, 'year': 1977},
#    {'records': 3858, 'species': 168, 'taxa': 209, 'year': 1978},
#    {'records': 4379, 'species': 183, 'taxa': 223, 'year': 1979},
#    {'records': 5349, 'species': 206, 'taxa': 244, 'year': 1980},
#    {'records': 4965, 'species': 231, 'taxa': 295, 'year': 1981},
#    {'records': 5078, 'species': 233, 'taxa': 279, 'year': 1982},
#    {'records': 4729, 'species': 255, 'taxa': 326, 'year': 1983},
#    {'records': 5066, 'species': 275, 'taxa': 342, 'year': 1984},
#    {'records': 6091, 'species': 253, 'taxa': 324, 'year': 1985},
#    {'records': 5733, 'species': 220, 'taxa': 291, 'year': 1986},
#    {'records': 4516, 'species': 272, 'taxa': 345, 'year': 1987},
#    {'records': 4135, 'species': 142, 'taxa': 183, 'year': 1988},
#    {'records': 9974, 'species': 297, 'taxa': 362, 'year': 1989},
#    {'records': 6249, 'species': 241, 'taxa': 303, 'year': 1990},
#    {'records': 7234, 'species': 149, 'taxa': 216, 'year': 1991},
#    {'records': 8052, 'species': 121, 'taxa': 160, 'year': 1992},
#    {'records': 1668, 'species': 100, 'taxa': 136, 'year': 1993},
#    {'records': 2418, 'species': 150, 'taxa': 192, 'year': 1994},
#    {'records': 7074, 'species': 281, 'taxa': 362, 'year': 1995},
#    {'records': 8832, 'species': 188, 'taxa': 253, 'year': 1996},
#    {'records': 7566, 'species': 257, 'taxa': 333, 'year': 1997},
#    {'records': 9808, 'species': 258, 'taxa': 348, 'year': 1998},
#    {'records': 4465, 'species': 87, 'taxa': 120, 'year': 1999},
#    {'records': 6080, 'species': 114, 'taxa': 152, 'year': 2000},
#    {'records': 8325, 'species': 224, 'taxa': 284, 'year': 2001},
#    {'records': 4590, 'species': 130, 'taxa': 185, 'year': 2002},
#    {'records': 9406, 'species': 98, 'taxa': 154, 'year': 2003},
#    {'records': 5539, 'species': 92, 'taxa': 138, 'year': 2004},
#    {'records': 9797, 'species': 126, 'taxa': 179, 'year': 2005},
#    {'records': 6010, 'species': 123, 'taxa': 175, 'year': 2006},
#    {'records': 3393, 'species': 96, 'taxa': 145, 'year': 2007},
#    {'records': 5487, 'species': 99, 'taxa': 142, 'year': 2008},
#    {'records': 7453, 'species': 107, 'taxa': 146, 'year': 2009},
#    {'records': 5643, 'species': 88, 'taxa': 127, 'year': 2010},
#    {'records': 6158, 'species': 109, 'taxa': 165, 'year': 2011},
#    {'records': 6647, 'species': 110, 'taxa': 175, 'year': 2012},
#    {'records': 5709, 'species': 111, 'taxa': 163, 'year': 2013},
#    {'records': 6661, 'species': 97, 'taxa': 137, 'year': 2014},
#    {'records': 6009, 'species': 83, 'taxa': 120, 'year': 2015},
#    {'records': 20519, 'species': 106, 'taxa': 260, 'year': 2016},
#    {'records': 87, 'species': 17, 'taxa': 24, 'year': 2017},
#    {'records': 60, 'species': 13, 'taxa': 20, 'year': 2018}],
#   'area_type': 'abnj',
#   'datasets': 71,
#   'date_cached': '2019-02-28T23:21:16.774755',
#   'eov_label': 'Phytoplankton biomass and diversity',
#   'eov_name': 'phytoplankton',
#   'eov_taxonomic_names': ['Chlorophyceae',
#    'Chrysophyceae',
#    'Cryptophyceae',
#    'Cyanophyceae',
#    'Diatomophyceae',
#    'Dictyochophyceae',
#    'Dinophyceae',
#    'Euglenophyceae',
#    'Eustigmatophyceae',
#    'Micromonadophyceae',
#    'Pedinophyceae',
#    'Prasinophyceae',
#    'Prymnesiophyceae',
#    'Raphidophyceae',
#    'Rhodophyceae',
#    'Tribophyceae'],
#   'eov_url': 'http://www.goosocean.org/index.php?option=com_oe&task=viewDocumentRecord&docID=17507',
#   'records': 352511,
#   'species': 1367,
#   'specieslevel': 205091,
#   'taxa': 1938,
#   'yearrange': [1900, 2018]},
#  {'area_id': '10002',
#   'area_name': 'Abrolhos bank and Vitória-Trindade Chain',
#   'area_records_per_year': [{'records': 40,
#     'species': 12,
#     'taxa': 15,
#     'year': 1989},
#    {'records': 386, 'species': 96, 'taxa': 121, 'year': 1995},
#    {'records': 2, 'species': 0, 'taxa': 2, 'year': 1997},
#    {'records': 288, 'species': 58, 'taxa': 59, 'year': 2000},
#    {'records': 10, 'species': 5, 'taxa': 5, 'year': 2014},
#    {'records': 1, 'species': 1, 'taxa': 1, 'year': 2016}],
#   'area_type': 'ebsa',
#   'datasets': 6,
#   'date_cached': '2019-02-28T23:21:18.138955',
#   'eov_label': 'Phytoplankton biomass and diversity',
#   'eov_name': 'phytoplankton',
#   'eov_taxonomic_names': ['Chlorophyceae',
#    'Chrysophyceae',
#    'Cryptophyceae',
#    'Cyanophyceae',
#    'Diatomophyceae',
#    'Dictyochophyceae',
#    'Dinophyceae',
#    'Euglenophyceae',
#    'Eustigmatophyceae',
#    'Micromonadophyceae',
#    'Pedinophyceae',
#    'Prasinophyceae',
#    'Prymnesiophyceae',
#    'Raphidophyceae',
#    'Rhodophyceae',
#    'Tribophyceae'],
#   'eov_url': 'http://www.goosocean.org/index.php?option=com_oe&task=viewDocumentRecord&docID=17507',
#   'records': 754,
#   'species': 160,
#   'specieslevel': 653,
#   'taxa': 192,
#   'yearrange': [1989, 2016]},
#  {'area_id': '33314',
#   'area_name': 'Adriatic Sea',
#   'area_records_per_year': [{'records': 3,
#     'species': 0,
#     'taxa': 1,
#     'year': 1967},
#    {'records': 2, 'species': 0, 'taxa': 1, 'year': 1968},
#    {'records': 1, 'species': 0, 'taxa': 1, 'year': 1969},
#    {'records': 753, 'species': 76, 'taxa': 96, 'year': 1986},
#    {'records': 492, 'species': 64, 'taxa': 85, 'year': 1987},
#    {'records': 461, 'species': 58, 'taxa': 76, 'year': 1988},
#    {'records': 584, 'species': 65, 'taxa': 91, 'year': 1989},
#    {'records': 2091, 'species': 79, 'taxa': 126, 'year': 1990},
#    {'records': 1555, 'species': 74, 'taxa': 123, 'year': 1991},
#    {'records': 2483, 'species': 99, 'taxa': 157, 'year': 1992},
#    {'records': 1837, 'species': 71, 'taxa': 118, 'year': 1993},
#    {'records': 583, 'species': 59, 'taxa': 97, 'year': 1994},
#    {'records': 2927, 'species': 134, 'taxa': 192, 'year': 1995},
#    {'records': 1228, 'species': 88, 'taxa': 141, 'year': 1996},
#    {'records': 570, 'species': 38, 'taxa': 73, 'year': 1997},
#    {'records': 1230, 'species': 80, 'taxa': 123, 'year': 1998},
#    {'records': 2470, 'species': 104, 'taxa': 163, 'year': 1999},
#    {'records': 2845, 'species': 135, 'taxa': 196, 'year': 2000},
#    {'records': 2967, 'species': 134, 'taxa': 200, 'year': 2001},
#    {'records': 2346, 'species': 142, 'taxa': 199, 'year': 2002},
#    {'records': 3326, 'species': 166, 'taxa': 244, 'year': 2003},
#    {'records': 3578, 'species': 185, 'taxa': 268, 'year': 2004},
#    {'records': 2688, 'species': 175, 'taxa': 246, 'year': 2005},
#    {'records': 1143, 'species': 97, 'taxa': 138, 'year': 2006},
#    {'records': 1344, 'species': 112, 'taxa': 156, 'year': 2007},
#    {'records': 5778, 'species': 289, 'taxa': 395, 'year': 2008},
#    {'records': 3203, 'species': 189, 'taxa': 262, 'year': 2009},
#    {'records': 1464, 'species': 121, 'taxa': 166, 'year': 2010},
#    {'records': 1502, 'species': 124, 'taxa': 169, 'year': 2011},
#    {'records': 1496, 'species': 121, 'taxa': 167, 'year': 2012},
#    {'records': 1752, 'species': 122, 'taxa': 176, 'year': 2013},
#    {'records': 2087, 'species': 168, 'taxa': 226, 'year': 2014},
#    {'records': 1654, 'species': 160, 'taxa': 211, 'year': 2015},
#    {'records': 460, 'species': 90, 'taxa': 132, 'year': 2016}],
#   'area_type': 'iho',
#   'datasets': 29,
#   'date_cached': '2019-02-28T23:21:19.513678',
#   'eov_label': 'Phytoplankton biomass and diversity',
#   'eov_name': 'phytoplankton',
#   'eov_taxonomic_names': ['Chlorophyceae',
#    'Chrysophyceae',
#    'Cryptophyceae',
#    'Cyanophyceae',
#    'Diatomophyceae',
#    'Dictyochophyceae',
#    'Dinophyceae',
#    'Euglenophyceae',
#    'Eustigmatophyceae',
#    'Micromonadophyceae',
#    'Pedinophyceae',
#    'Prasinophyceae',
#    'Prymnesiophyceae',
#    'Raphidophyceae',
#    'Rhodophyceae',
#    'Tribophyceae'],
#   'eov_url': 'http://www.goosocean.org/index.php?option=com_oe&task=viewDocumentRecord&docID=17507',
#   'records': 513162,
#   'species': 622,
#   'specieslevel': 351969,
#   'taxa': 828,
#   'yearrange': [1967, 2016]},
#  {'area_id': '33315',
#   'area_name': 'Aegean Sea',
#   'area_records_per_year': [{'records': 145,
#     'species': 40,
#     'taxa': 57,
#     'year': 1970},
#    {'records': 269, 'species': 44, 'taxa': 62, 'year': 1987},
#    {'records': 113, 'species': 16, 'taxa': 20, 'year': 1988},
#    {'records': 20, 'species': 5, 'taxa': 9, 'year': 1989},
#    {'records': 16, 'species': 6, 'taxa': 10, 'year': 1991},
#    {'records': 7, 'species': 5, 'taxa': 7, 'year': 1992},
#    {'records': 191, 'species': 31, 'taxa': 38, 'year': 1994},
#    {'records': 20, 'species': 10, 'taxa': 14, 'year': 1995},
#    {'records': 1019, 'species': 97, 'taxa': 116, 'year': 1997},
#    {'records': 195, 'species': 66, 'taxa': 72, 'year': 1998},
#    {'records': 7, 'species': 0, 'taxa': 1, 'year': 2004}],
#   'area_type': 'iho',
#   'datasets': 7,
#   'date_cached': '2019-02-28T23:21:21.430025',
#   'eov_label': 'Phytoplankton biomass and diversity',
#   'eov_name': 'phytoplankton',
#   'eov_taxonomic_names': ['Chlorophyceae',
#    'Chrysophyceae',
#    'Cryptophyceae',
#    'Cyanophyceae',
#    'Diatomophyceae',
#    'Dictyochophyceae',
#    'Dinophyceae',
#    'Euglenophyceae',
#    'Eustigmatophyceae',
#    'Micromonadophyceae',
#    'Pedinophyceae',
#    'Prasinophyceae',
#    'Prymnesiophyceae',
#    'Raphidophyceae',
#    'Rhodophyceae',
#    'Tribophyceae'],
#   'eov_url': 'http://www.goosocean.org/index.php?option=com_oe&task=viewDocumentRecord&docID=17507',
#   'records': 2006,
#   'species': 185,
#   'specieslevel': 1417,
#   'taxa': 244,
#   'yearrange': [1970, 2004]}]
# 5
